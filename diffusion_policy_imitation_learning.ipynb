# %%
# !python --version
# !pip3 install torch==1.13.1 torchvision==0.14.1 diffusers==0.18.2 \
scikit-image==0.19.3 scikit-video==1.1.11 \
pygame==2.1.2 pymunk==6.2.1 gym==0.26.2 shapely==1.8.4 \
&> /dev/null # Mute output for cleaner logs

# !pip install zarr==2.12.0
# !pip install numcodecs==0.10.2
# !pip install scikit-video==1.1.11
# !pip install torch_optimizer
# !pip install numpy==1.25.2
# !pip install pyvirtualdisplay
# !pip install pymunk==6.2.1
# !pip install torch-ema

# Setup Vulkan for ManiSkill on Colab
# !sudo mkdir -p /usr/share/vulkan/icd.d
# !sudo mkdir -p /usr/share/glvnd/egl_vendor.d
# !wget -q https://raw.githubusercontent.com/haosulab/ManiSkill/main/docker/nvidia_icd.json
# !wget -q https://raw.githubusercontent.com/haosulab/ManiSkill/main/docker/10_nvidia.json
# !sudo mv nvidia_icd.json /usr/share/vulkan/icd.d/
# !sudo mv 10_nvidia.json /usr/share/glvnd/egl_vendor.d/10_nvidia.json
# !sudo apt-get update
# !sudo apt-get install -y --no-install-recommends libvulkan-dev

# Install ManiSkill dependencies
# !pip install -U "mani_skill[dev]" tyro
# !pip install mani-skill2
# Out:
# Python 3.11.12
# Requirement already satisfied: zarr==2.12.0 in /usr/local/lib/python3.11/dist-packages (2.12.0)
# Requirement already satisfied: asciitree in /usr/local/lib/python3.11/dist-packages (from zarr==2.12.0) (0.3.3)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.11/dist-packages (from zarr==2.12.0) (1.25.2)
# Requirement already satisfied: fasteners in /usr/local/lib/python3.11/dist-packages (from zarr==2.12.0) (0.19)
# Requirement already satisfied: numcodecs>=0.6.4 in /usr/local/lib/python3.11/dist-packages (from zarr==2.12.0) (0.10.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.11/dist-packages (from numcodecs>=0.6.4->zarr==2.12.0) (0.4)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.11/dist-packages (from numcodecs>=0.6.4->zarr==2.12.0) (4.13.2)
# Requirement already satisfied: numcodecs==0.10.2 in /usr/local/lib/python3.11/dist-packages (0.10.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.11/dist-packages (from numcodecs==0.10.2) (0.4)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.11/dist-packages (from numcodecs==0.10.2) (1.25.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.11/dist-packages (from numcodecs==0.10.2) (4.13.2)
# Requirement already satisfied: scikit-video==1.1.11 in /usr/local/lib/python3.11/dist-packages (1.1.11)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from scikit-video==1.1.11) (1.25.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from scikit-video==1.1.11) (11.2.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from scikit-video==1.1.11) (1.15.2)
# Requirement already satisfied: torch_optimizer in /usr/local/lib/python3.11/dist-packages (0.3.0)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from torch_optimizer) (2.6.0+cu124)
# Requirement already satisfied: pytorch-ranger>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from torch_optimizer) (0.1.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch_optimizer) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch_optimizer) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch_optimizer) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch_optimizer) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch_optimizer) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch_optimizer) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch_optimizer) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch_optimizer) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch_optimizer) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch_optimizer) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch_optimizer) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch_optimizer) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch_optimizer) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch_optimizer) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch_optimizer) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch_optimizer) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch_optimizer) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch_optimizer) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch_optimizer) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch_optimizer) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.5.0->torch_optimizer) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.5.0->torch_optimizer) (3.0.2)
# Requirement already satisfied: numpy==1.25.2 in /usr/local/lib/python3.11/dist-packages (1.25.2)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.11/dist-packages (3.0)
# Collecting pymunk==6.2.1
#   Downloading pymunk-6.2.1.zip (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 66.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: cffi>=1.15.0 in /usr/local/lib/python3.11/dist-packages (from pymunk==6.2.1) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.15.0->pymunk==6.2.1) (2.22)
# Building wheels for collected packages: pymunk
#   Building wheel for pymunk (pyproject.toml) ... done
#   Created wheel for pymunk: filename=pymunk-6.2.1-cp311-cp311-linux_x86_64.whl size=801783 sha256=3b9433f0bdf2c3958cbd8e7f9eace48ef9300d3fe3327fb66469f0af168f2f02
#   Stored in directory: /root/.cache/pip/wheels/16/23/6d/2e713157384d80a5b142e50188d3707f1146d0e3231a4f2157
# Successfully built pymunk
# Installing collected packages: pymunk
# Successfully installed pymunk-6.2.1
# Collecting torch-ema
#   Downloading torch_ema-0.3-py3-none-any.whl.metadata (415 bytes)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from torch-ema) (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->torch-ema) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->torch-ema) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->torch-ema) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->torch-ema) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->torch-ema) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->torch-ema) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->torch-ema) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->torch-ema) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->torch-ema) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->torch-ema) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->torch-ema) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->torch-ema) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->torch-ema) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->torch-ema) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->torch-ema) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->torch-ema) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->torch-ema) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->torch-ema) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->torch-ema) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->torch-ema) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->torch-ema) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->torch-ema) (3.0.2)
# Downloading torch_ema-0.3-py3-none-any.whl (5.5 kB)
# Installing collected packages: torch-ema
# Successfully installed torch-ema-0.3
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,872 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,844 kB]
# Get:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,244 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:14 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,704 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,543 kB]
# Get:16 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [46.3 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,155 kB]
# Fetched 20.8 MB in 2s (8,769 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libvulkan-dev is already the newest version (1.3.204.1-2).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# Collecting tyro
#   Downloading tyro-0.9.19-py3-none-any.whl.metadata (9.9 kB)
# Collecting mani_skill[dev]
#   Downloading mani_skill-3.0.0b20-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.22 in /usr/local/lib/python3.11/dist-packages (from mani_skill[dev]) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mani_skill[dev]) (1.15.2)
# Collecting dacite (from mani_skill[dev])
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Collecting gymnasium==0.29.1 (from mani_skill[dev])
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Collecting sapien==3.0.0.b1 (from mani_skill[dev])
#   Downloading sapien-3.0.0b1-cp311-cp311-manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from mani_skill[dev]) (3.13.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from mani_skill[dev]) (6.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from mani_skill[dev]) (4.67.1)
# Requirement already satisfied: GitPython in /usr/local/lib/python3.11/dist-packages (from mani_skill[dev]) (3.1.44)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from mani_skill[dev]) (0.9.0)
# Collecting transforms3d (from mani_skill[dev])
#   Downloading transforms3d-0.4.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting trimesh (from mani_skill[dev])
#   Downloading trimesh-4.6.8-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: imageio in /usr/local/lib/python3.11/dist-packages (from mani_skill[dev]) (2.37.0)
# Collecting mplib==0.1.1 (from mani_skill[dev])
#   Downloading mplib-0.1.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Collecting fast_kinematics==0.2.2 (from mani_skill[dev])
#   Downloading fast_kinematics-0.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: IPython in /usr/local/lib/python3.11/dist-packages (from mani_skill[dev]) (7.34.0)
# Collecting pytorch_kinematics==0.7.5 (from mani_skill[dev])
#   Downloading pytorch_kinematics-0.7.5-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pynvml in /usr/local/lib/python3.11/dist-packages (from mani_skill[dev]) (12.0.0)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (from mani_skill[dev]) (0.30.2)
# Requirement already satisfied: pytest in /usr/local/lib/python3.11/dist-packages (from mani_skill[dev]) (8.3.5)
# Collecting black (from mani_skill[dev])
#   Downloading black-25.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 4.1 MB/s eta 0:00:00
# Collecting isort (from mani_skill[dev])
#   Downloading isort-6.0.1-py3-none-any.whl.metadata (11 kB)
# Collecting pre-commit (from mani_skill[dev])
#   Downloading pre_commit-4.2.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting build (from mani_skill[dev])
#   Downloading build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Collecting twine (from mani_skill[dev])
#   Downloading twine-6.1.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting stable_baselines3 (from mani_skill[dev])
#   Downloading stable_baselines3-2.6.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting pytest-xdist[psutil] (from mani_skill[dev])
#   Downloading pytest_xdist-3.6.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting pytest-forked (from mani_skill[dev])
#   Downloading pytest_forked-1.6.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->mani_skill[dev]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->mani_skill[dev]) (4.13.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->mani_skill[dev]) (0.0.4)
# Collecting toppra>=0.4.0 (from mplib==0.1.1->mani_skill[dev])
#   Downloading toppra-0.6.3.tar.gz (256 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.1/256.1 kB 12.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from pytorch_kinematics==0.7.5->mani_skill[dev]) (1.4.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from pytorch_kinematics==0.7.5->mani_skill[dev]) (5.4.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from pytorch_kinematics==0.7.5->mani_skill[dev]) (2.6.0+cu124)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from pytorch_kinematics==0.7.5->mani_skill[dev]) (3.10.0)
# Collecting pytorch-seed (from pytorch_kinematics==0.7.5->mani_skill[dev])
#   Downloading pytorch_seed-0.2.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting arm-pytorch-utilities (from pytorch_kinematics==0.7.5->mani_skill[dev])
#   Downloading arm_pytorch_utilities-0.4.3-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: requests>=2.22 in /usr/local/lib/python3.11/dist-packages (from sapien==3.0.0.b1->mani_skill[dev]) (2.32.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from sapien==3.0.0.b1->mani_skill[dev]) (3.4.2)
# Requirement already satisfied: pyperclip in /usr/local/lib/python3.11/dist-packages (from sapien==3.0.0.b1->mani_skill[dev]) (1.9.0)
# Requirement already satisfied: opencv-python>=4.0 in /usr/local/lib/python3.11/dist-packages (from sapien==3.0.0.b1->mani_skill[dev]) (4.11.0.86)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.11/dist-packages (from tyro) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.11/dist-packages (from tyro) (13.9.4)
# Collecting shtab>=1.5.6 (from tyro)
#   Downloading shtab-1.7.2-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from tyro) (4.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1.0->tyro) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1.0->tyro) (2.19.1)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from black->mani_skill[dev]) (8.1.8)
# Collecting mypy-extensions>=0.4.3 (from black->mani_skill[dev])
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.11/dist-packages (from black->mani_skill[dev]) (24.2)
# Collecting pathspec>=0.9.0 (from black->mani_skill[dev])
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.11/dist-packages (from black->mani_skill[dev]) (4.3.7)
# Collecting pyproject_hooks (from build->mani_skill[dev])
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from GitPython->mani_skill[dev]) (4.0.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->mani_skill[dev]) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->mani_skill[dev]) (2025.3.2)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.11/dist-packages (from imageio->mani_skill[dev]) (11.2.1)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.11/dist-packages (from imageio[ffmpeg]->mani_skill[dev]) (0.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from imageio[ffmpeg]->mani_skill[dev]) (5.9.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from IPython->mani_skill[dev]) (75.2.0)
# Collecting jedi>=0.16 (from IPython->mani_skill[dev])
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from IPython->mani_skill[dev]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from IPython->mani_skill[dev]) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from IPython->mani_skill[dev]) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from IPython->mani_skill[dev]) (3.0.51)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from IPython->mani_skill[dev]) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from IPython->mani_skill[dev]) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from IPython->mani_skill[dev]) (4.9.0)
# Collecting cfgv>=2.0.0 (from pre-commit->mani_skill[dev])
#   Downloading cfgv-3.4.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting identify>=1.0.0 (from pre-commit->mani_skill[dev])
#   Downloading identify-2.6.10-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting nodeenv>=0.11.1 (from pre-commit->mani_skill[dev])
#   Downloading nodeenv-1.9.1-py2.py3-none-any.whl.metadata (21 kB)
# Collecting virtualenv>=20.10.0 (from pre-commit->mani_skill[dev])
#   Downloading virtualenv-20.30.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: nvidia-ml-py<13.0.0a0,>=12.0.0 in /usr/local/lib/python3.11/dist-packages (from pynvml->mani_skill[dev]) (12.570.86)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest->mani_skill[dev]) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest->mani_skill[dev]) (1.5.0)
# Collecting py (from pytest-forked->mani_skill[dev])
#   Downloading py-1.11.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting execnet>=2.1 (from pytest-xdist[psutil]; extra == "dev"->mani_skill[dev])
#   Downloading execnet-2.1.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable_baselines3->mani_skill[dev]) (2.2.2)
# Collecting readme-renderer>=35.0 (from twine->mani_skill[dev])
#   Downloading readme_renderer-44.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from twine->mani_skill[dev]) (1.0.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from twine->mani_skill[dev]) (2.4.0)
# Requirement already satisfied: keyring>=15.1 in /usr/local/lib/python3.11/dist-packages (from twine->mani_skill[dev]) (25.6.0)
# Collecting rfc3986>=1.4.0 (from twine->mani_skill[dev])
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting id (from twine->mani_skill[dev])
#   Downloading id-1.5.0-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->GitPython->mani_skill[dev]) (5.0.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->IPython->mani_skill[dev]) (0.8.4)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/local/lib/python3.11/dist-packages (from keyring>=15.1->twine->mani_skill[dev]) (3.3.3)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/local/lib/python3.11/dist-packages (from keyring>=15.1->twine->mani_skill[dev]) (0.9.0)
# Requirement already satisfied: importlib_metadata>=4.11.4 in /usr/local/lib/python3.11/dist-packages (from keyring>=15.1->twine->mani_skill[dev]) (8.6.1)
# Requirement already satisfied: jaraco.classes in /usr/local/lib/python3.11/dist-packages (from keyring>=15.1->twine->mani_skill[dev]) (3.4.0)
# Requirement already satisfied: jaraco.functools in /usr/local/lib/python3.11/dist-packages (from keyring>=15.1->twine->mani_skill[dev]) (4.1.0)
# Requirement already satisfied: jaraco.context in /usr/local/lib/python3.11/dist-packages (from keyring>=15.1->twine->mani_skill[dev]) (6.0.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->IPython->mani_skill[dev]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->mani_skill[dev]) (0.2.13)
# Collecting nh3>=0.2.14 (from readme-renderer>=35.0->twine->mani_skill[dev])
#   Downloading nh3-0.2.21-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: docutils>=0.21.2 in /usr/local/lib/python3.11/dist-packages (from readme-renderer>=35.0->twine->mani_skill[dev]) (0.21.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22->sapien==3.0.0.b1->mani_skill[dev]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22->sapien==3.0.0.b1->mani_skill[dev]) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22->sapien==3.0.0.b1->mani_skill[dev]) (2025.1.31)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->pytorch_kinematics==0.7.5->mani_skill[dev]) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->pytorch_kinematics==0.7.5->mani_skill[dev]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->pytorch_kinematics==0.7.5->mani_skill[dev]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->pytorch_kinematics==0.7.5->mani_skill[dev]) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->pytorch_kinematics==0.7.5->mani_skill[dev]) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->pytorch_kinematics==0.7.5->mani_skill[dev]) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->pytorch_kinematics==0.7.5->mani_skill[dev]) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->pytorch_kinematics==0.7.5->mani_skill[dev]) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->pytorch_kinematics==0.7.5->mani_skill[dev]) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->pytorch_kinematics==0.7.5->mani_skill[dev]) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->pytorch_kinematics==0.7.5->mani_skill[dev]) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->pytorch_kinematics==0.7.5->mani_skill[dev]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->pytorch_kinematics==0.7.5->mani_skill[dev]) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->pytorch_kinematics==0.7.5->mani_skill[dev]) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->pytorch_kinematics==0.7.5->mani_skill[dev]) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->pytorch_kinematics==0.7.5->mani_skill[dev]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->pytorch_kinematics==0.7.5->mani_skill[dev]) (1.3.0)
# Collecting distlib<1,>=0.3.7 (from virtualenv>=20.10.0->pre-commit->mani_skill[dev])
#   Downloading distlib-0.3.9-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pytorch_kinematics==0.7.5->mani_skill[dev]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pytorch_kinematics==0.7.5->mani_skill[dev]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pytorch_kinematics==0.7.5->mani_skill[dev]) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pytorch_kinematics==0.7.5->mani_skill[dev]) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pytorch_kinematics==0.7.5->mani_skill[dev]) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pytorch_kinematics==0.7.5->mani_skill[dev]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3->mani_skill[dev]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3->mani_skill[dev]) (2025.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata>=4.11.4->keyring>=15.1->twine->mani_skill[dev]) (3.21.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->pytorch_kinematics==0.7.5->mani_skill[dev]) (1.17.0)
# Requirement already satisfied: cryptography>=2.0 in /usr/local/lib/python3.11/dist-packages (from SecretStorage>=3.2->keyring>=15.1->twine->mani_skill[dev]) (43.0.3)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.11/dist-packages (from jaraco.classes->keyring>=15.1->twine->mani_skill[dev]) (10.7.0)
# Requirement already satisfied: backports.tarfile in /usr/local/lib/python3.11/dist-packages (from jaraco.context->keyring>=15.1->twine->mani_skill[dev]) (1.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->pytorch_kinematics==0.7.5->mani_skill[dev]) (3.0.2)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring>=15.1->twine->mani_skill[dev]) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring>=15.1->twine->mani_skill[dev]) (2.22)
# Downloading fast_kinematics-0.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (624 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 624.7/624.7 kB 35.3 MB/s eta 0:00:00
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 54.0 MB/s eta 0:00:00
# Downloading mplib-0.1.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 98.3 MB/s eta 0:00:00
# Downloading pytorch_kinematics-0.7.5-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 5.7 MB/s eta 0:00:00
# Downloading sapien-3.0.0b1-cp311-cp311-manylinux2014_x86_64.whl (49.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 MB 15.9 MB/s eta 0:00:00
# Downloading tyro-0.9.19-py3-none-any.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.3/124.3 kB 12.2 MB/s eta 0:00:00
# Downloading shtab-1.7.2-py3-none-any.whl (14 kB)
# Downloading transforms3d-0.4.2-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 69.7 MB/s eta 0:00:00
# Downloading black-25.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 80.5 MB/s eta 0:00:00
# Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading isort-6.0.1-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.2/94.2 kB 9.1 MB/s eta 0:00:00
# Downloading mani_skill-3.0.0b20-py3-none-any.whl (96.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 MB 9.9 MB/s eta 0:00:00
# Downloading pre_commit-4.2.0-py2.py3-none-any.whl (220 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.7/220.7 kB 16.8 MB/s eta 0:00:00
# Downloading pytest_forked-1.6.0-py3-none-any.whl (4.9 kB)
# Downloading stable_baselines3-2.6.0-py3-none-any.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.5/184.5 kB 15.6 MB/s eta 0:00:00
# Downloading trimesh-4.6.8-py3-none-any.whl (709 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 709.3/709.3 kB 34.4 MB/s eta 0:00:00
# Downloading twine-6.1.0-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 3.0 MB/s eta 0:00:00
# Downloading cfgv-3.4.0-py2.py3-none-any.whl (7.2 kB)
# Downloading execnet-2.1.1-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 kB 3.8 MB/s eta 0:00:00
# Downloading identify-2.6.10-py2.py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.8 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 64.4 MB/s eta 0:00:00
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading nodeenv-1.9.1-py2.py3-none-any.whl (22 kB)
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading readme_renderer-44.0-py3-none-any.whl (13 kB)
# Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Downloading virtualenv-20.30.0-py3-none-any.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 88.1 MB/s eta 0:00:00
# Downloading arm_pytorch_utilities-0.4.3-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 3.6 MB/s eta 0:00:00
# Downloading id-1.5.0-py3-none-any.whl (13 kB)
# Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 kB 9.1 MB/s eta 0:00:00
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading pytest_xdist-3.6.1-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 4.3 MB/s eta 0:00:00
# Downloading pytorch_seed-0.2.0-py3-none-any.whl (4.2 kB)
# Downloading distlib-0.3.9-py2.py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 31.7 MB/s eta 0:00:00
# Downloading nh3-0.2.21-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (739 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.0/739.0 kB 42.5 MB/s eta 0:00:00
# Building wheels for collected packages: toppra
#   Building wheel for toppra (pyproject.toml) ... done
#   Created wheel for toppra: filename=toppra-0.6.3-cp311-cp311-linux_x86_64.whl size=788023 sha256=c431c9ef1604c7040bdcae1a6159654f4ef490a9e68beba49b8056789637aa50
#   Stored in directory: /root/.cache/pip/wheels/57/59/c1/4daf9fdaf34e03a2d94430efe8b070346c86b15bc9d446c162
# Successfully built toppra
# Installing collected packages: distlib, virtualenv, trimesh, transforms3d, shtab, rfc3986, pyproject_hooks, py, pathspec, nodeenv, nh3, mypy-extensions, jedi, isort, identify, gymnasium, fast_kinematics, execnet, dacite, cfgv, sapien, readme-renderer, pytest-xdist, pytest-forked, pre-commit, id, build, black, tyro, toppra, stable_baselines3, pytorch-seed, mplib, twine, arm-pytorch-utilities, pytorch_kinematics, mani_skill
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.1.1
#     Uninstalling gymnasium-1.1.1:
#       Successfully uninstalled gymnasium-1.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.1 which is incompatible.
# Successfully installed arm-pytorch-utilities-0.4.3 black-25.1.0 build-1.2.2.post1 cfgv-3.4.0 dacite-1.9.2 distlib-0.3.9 execnet-2.1.1 fast_kinematics-0.2.2 gymnasium-0.29.1 id-1.5.0 identify-2.6.10 isort-6.0.1 jedi-0.19.2 mani_skill-3.0.0b20 mplib-0.1.1 mypy-extensions-1.1.0 nh3-0.2.21 nodeenv-1.9.1 pathspec-0.12.1 pre-commit-4.2.0 py-1.11.0 pyproject_hooks-1.2.0 pytest-forked-1.6.0 pytest-xdist-3.6.1 pytorch-seed-0.2.0 pytorch_kinematics-0.7.5 readme-renderer-44.0 rfc3986-2.0.0 sapien-3.0.0b1 shtab-1.7.2 stable_baselines3-2.6.0 toppra-0.6.3 transforms3d-0.4.2 trimesh-4.6.8 twine-6.1.0 tyro-0.9.19 virtualenv-20.30.0

# %%
# start virtual display
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()

# %%
# import libraries
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import numpy as np
import zarr
import gym
from diffusers import DDPMScheduler
from torch.utils.data import DataLoader
import collections
from tqdm import tqdm
from transformers import get_scheduler
import os
import gdown
import math
from IPython.display import Video
import skvideo.io
import pygame
import pymunk
from pymunk.vec2d import Vec2d
from pymunk.space_debug_draw_options import SpaceDebugColor
from typing import Tuple, Sequence, Dict, Union, Optional, Callable

import cv2
import shapely.geometry as sg
import shapely.affinity as st
# from torch_ema import ExponentialMovingAverage as EMAModel
from diffusers.training_utils import EMAModel
# Out:
# /usr/local/lib/python3.11/dist-packages/skvideo/utils/stpyr.py:2: DeprecationWarning: scipy.misc is deprecated and will be removed in 2.0.0
#   import scipy.misc as sc
# /usr/local/lib/python3.11/dist-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)

# %%
#@markdown ### **Environment**
#@markdown Defines a PyMunk-based Push-T environment `PushTEnv`.
#@markdown And it's subclass `PushTImageEnv`.
#@markdown
#@markdown **Goal**: push the gray T-block into the green area.
#@markdown
#@markdown Adapted from [Implicit Behavior Cloning](https://implicitbc.github.io/)


positive_y_is_up: bool = False
"""Make increasing values of y point upwards.

When True::

    y
    ^
    |      . (3, 3)
    |
    |   . (2, 2)
    |
    +------ > x

When False::

    +------ > x
    |
    |   . (2, 2)
    |
    |      . (3, 3)
    v
    y

"""

def to_pygame(p: Tuple[float, float], surface: pygame.Surface) -> Tuple[int, int]:
    """Convenience method to convert pymunk coordinates to pygame surface
    local coordinates.

    Note that in case positive_y_is_up is False, this function wont actually do
    anything except converting the point to integers.
    """
    if positive_y_is_up:
        return round(p[0]), surface.get_height() - round(p[1])
    else:
        return round(p[0]), round(p[1])


def light_color(color: SpaceDebugColor):
    color = np.minimum(1.2 * np.float32([color.r, color.g, color.b, color.a]), np.float32([255]))
    color = SpaceDebugColor(r=color[0], g=color[1], b=color[2], a=color[3])
    return color

class DrawOptions(pymunk.SpaceDebugDrawOptions):
    def __init__(self, surface: pygame.Surface) -> None:
        """Draw a pymunk.Space on a pygame.Surface object.

        Typical usage::

        >>> import pymunk
        >>> surface = pygame.Surface((10,10))
        >>> space = pymunk.Space()
        >>> options = pymunk.pygame_util.DrawOptions(surface)
        >>> space.debug_draw(options)

        You can control the color of a shape by setting shape.color to the color
        you want it drawn in::

        >>> c = pymunk.Circle(None, 10)
        >>> c.color = pygame.Color("pink")

        See pygame_util.demo.py for a full example

        Since pygame uses a coordiante system where y points down (in contrast
        to many other cases), you either have to make the physics simulation
        with Pymunk also behave in that way, or flip everything when you draw.

        The easiest is probably to just make the simulation behave the same
        way as Pygame does. In that way all coordinates used are in the same
        orientation and easy to reason about::

        >>> space = pymunk.Space()
        >>> space.gravity = (0, -1000)
        >>> body = pymunk.Body()
        >>> body.position = (0, 0) # will be positioned in the top left corner
        >>> space.debug_draw(options)

        To flip the drawing its possible to set the module property
        :py:data:`positive_y_is_up` to True. Then the pygame drawing will flip
        the simulation upside down before drawing::

        >>> positive_y_is_up = True
        >>> body = pymunk.Body()
        >>> body.position = (0, 0)
        >>> # Body will be position in bottom left corner

        :Parameters:
                surface : pygame.Surface
                    Surface that the objects will be drawn on
        """
        self.surface = surface
        super(DrawOptions, self).__init__()

    def draw_circle(
        self,
        pos: Vec2d,
        angle: float,
        radius: float,
        outline_color: SpaceDebugColor,
        fill_color: SpaceDebugColor,
    ) -> None:
        p = to_pygame(pos, self.surface)

        pygame.draw.circle(self.surface, fill_color.as_int(), p, round(radius), 0)
        pygame.draw.circle(self.surface, light_color(fill_color).as_int(), p, round(radius-4), 0)

        circle_edge = pos + Vec2d(radius, 0).rotated(angle)
        p2 = to_pygame(circle_edge, self.surface)
        line_r = 2 if radius > 20 else 1
        # pygame.draw.lines(self.surface, outline_color.as_int(), False, [p, p2], line_r)

    def draw_segment(self, a: Vec2d, b: Vec2d, color: SpaceDebugColor) -> None:
        p1 = to_pygame(a, self.surface)
        p2 = to_pygame(b, self.surface)

        pygame.draw.aalines(self.surface, color.as_int(), False, [p1, p2])

    def draw_fat_segment(
        self,
        a: Tuple[float, float],
        b: Tuple[float, float],
        radius: float,
        outline_color: SpaceDebugColor,
        fill_color: SpaceDebugColor,
    ) -> None:
        p1 = to_pygame(a, self.surface)
        p2 = to_pygame(b, self.surface)

        r = round(max(1, radius * 2))
        pygame.draw.lines(self.surface, fill_color.as_int(), False, [p1, p2], r)
        if r > 2:
            orthog = [abs(p2[1] - p1[1]), abs(p2[0] - p1[0])]
            if orthog[0] == 0 and orthog[1] == 0:
                return
            scale = radius / (orthog[0] * orthog[0] + orthog[1] * orthog[1]) ** 0.5
            orthog[0] = round(orthog[0] * scale)
            orthog[1] = round(orthog[1] * scale)
            points = [
                (p1[0] - orthog[0], p1[1] - orthog[1]),
                (p1[0] + orthog[0], p1[1] + orthog[1]),
                (p2[0] + orthog[0], p2[1] + orthog[1]),
                (p2[0] - orthog[0], p2[1] - orthog[1]),
            ]
            pygame.draw.polygon(self.surface, fill_color.as_int(), points)
            pygame.draw.circle(
                self.surface,
                fill_color.as_int(),
                (round(p1[0]), round(p1[1])),
                round(radius),
            )
            pygame.draw.circle(
                self.surface,
                fill_color.as_int(),
                (round(p2[0]), round(p2[1])),
                round(radius),
            )

    def draw_polygon(
        self,
        verts: Sequence[Tuple[float, float]],
        radius: float,
        outline_color: SpaceDebugColor,
        fill_color: SpaceDebugColor,
    ) -> None:
        ps = [to_pygame(v, self.surface) for v in verts]
        ps += [ps[0]]

        radius = 2
        pygame.draw.polygon(self.surface, light_color(fill_color).as_int(), ps)

        if radius > 0:
            for i in range(len(verts)):
                a = verts[i]
                b = verts[(i + 1) % len(verts)]
                self.draw_fat_segment(a, b, radius, fill_color, fill_color)

    def draw_dot(
        self, size: float, pos: Tuple[float, float], color: SpaceDebugColor
    ) -> None:
        p = to_pygame(pos, self.surface)
        pygame.draw.circle(self.surface, color.as_int(), p, round(size), 0)


def pymunk_to_shapely(body, shapes):
    geoms = list()
    for shape in shapes:
        if isinstance(shape, pymunk.shapes.Poly):
            verts = [body.local_to_world(v) for v in shape.get_vertices()]
            verts += [verts[0]]
            geoms.append(sg.Polygon(verts))
        else:
            raise RuntimeError(f'Unsupported shape type {type(shape)}')
    geom = sg.MultiPolygon(geoms)
    return geom

# env
class PushTEnv(gym.Env):
    metadata = {"render.modes": ["human", "rgb_array"], "video.frames_per_second": 10}
    reward_range = (0., 1.)

    def __init__(self,
            legacy=False,
            block_cog=None, damping=None,
            render_action=True,
            render_size=96,
            reset_to_state=None
        ):
        self._seed = None
        self.seed()
        self.window_size = ws = 512  # The size of the PyGame window
        self.render_size = render_size
        self.sim_hz = 100
        # Local controller params.
        self.k_p, self.k_v = 100, 20    # PD control.z
        self.control_hz = self.metadata['video.frames_per_second']
        # legcay set_state for data compatiblity
        self.legacy = legacy

        # agent_pos, block_pos, block_angle
        self.observation_space = spaces.Box(
            low=np.array([0,0,0,0,0], dtype=np.float64),
            high=np.array([ws,ws,ws,ws,np.pi*2], dtype=np.float64),
            shape=(5,),
            dtype=np.float64
        )

        # positional goal for agent
        self.action_space = spaces.Box(
            low=np.array([0,0], dtype=np.float64),
            high=np.array([ws,ws], dtype=np.float64),
            shape=(2,),
            dtype=np.float64
        )

        self.block_cog = block_cog
        self.damping = damping
        self.render_action = render_action

        """
        If human-rendering is used, `self.window` will be a reference
        to the window that we draw to. `self.clock` will be a clock that is used
        to ensure that the environment is rendered at the correct framerate in
        human-mode. They will remain `None` until human-mode is used for the
        first time.
        """
        self.window = None
        self.clock = None
        self.screen = None

        self.space = None
        self.teleop = None
        self.render_buffer = None
        self.latest_action = None
        self.reset_to_state = reset_to_state

    def reset(self):
        seed = self._seed
        self._setup()
        if self.block_cog is not None:
            self.block.center_of_gravity = self.block_cog
        if self.damping is not None:
            self.space.damping = self.damping

        # use legacy RandomState for compatiblity
        state = self.reset_to_state
        if state is None:
            rs = np.random.RandomState(seed=seed)
            state = np.array([
                rs.randint(50, 450), rs.randint(50, 450),
                rs.randint(100, 400), rs.randint(100, 400),
                rs.randn() * 2 * np.pi - np.pi
                ])
        self._set_state(state)

        obs = self._get_obs()
        info = self._get_info()
        return obs, info

    def step(self, action):
        dt = 1.0 / self.sim_hz
        self.n_contact_points = 0
        n_steps = self.sim_hz // self.control_hz
        if action is not None:
            self.latest_action = action
            for i in range(n_steps):
                # Step PD control.
                # self.agent.velocity = self.k_p * (act - self.agent.position)    # P control works too.
                acceleration = self.k_p * (action - self.agent.position) + self.k_v * (Vec2d(0, 0) - self.agent.velocity)
                self.agent.velocity += acceleration * dt

                # Step physics.
                self.space.step(dt)

        # compute reward
        goal_body = self._get_goal_pose_body(self.goal_pose)
        goal_geom = pymunk_to_shapely(goal_body, self.block.shapes)
        block_geom = pymunk_to_shapely(self.block, self.block.shapes)

        intersection_area = goal_geom.intersection(block_geom).area
        goal_area = goal_geom.area
        coverage = intersection_area / goal_area
        reward = np.clip(coverage / self.success_threshold, 0, 1)
        done = coverage > self.success_threshold
        terminated = done
        truncated = done

        observation = self._get_obs()
        info = self._get_info()

        return observation, reward, terminated, truncated, info

    def render(self, mode):
        return self._render_frame(mode)

    def teleop_agent(self):
        TeleopAgent = collections.namedtuple('TeleopAgent', ['act'])
        def act(obs):
            act = None
            mouse_position = pymunk.pygame_util.from_pygame(Vec2d(*pygame.mouse.get_pos()), self.screen)
            if self.teleop or (mouse_position - self.agent.position).length < 30:
                self.teleop = True
                act = mouse_position
            return act
        return TeleopAgent(act)

    def _get_obs(self):
        obs = np.array(
            tuple(self.agent.position) \
            + tuple(self.block.position) \
            + (self.block.angle % (2 * np.pi),))
        return obs

    def _get_goal_pose_body(self, pose):
        mass = 1
        inertia = pymunk.moment_for_box(mass, (50, 100))
        body = pymunk.Body(mass, inertia)
        # preserving the legacy assignment order for compatibility
        # the order here dosn't matter somehow, maybe because CoM is aligned with body origin
        body.position = pose[:2].tolist()
        body.angle = pose[2]
        return body

    def _get_info(self):
        n_steps = self.sim_hz // self.control_hz
        n_contact_points_per_step = int(np.ceil(self.n_contact_points / n_steps))
        info = {
            'pos_agent': np.array(self.agent.position),
            'vel_agent': np.array(self.agent.velocity),
            'block_pose': np.array(list(self.block.position) + [self.block.angle]),
            'goal_pose': self.goal_pose,
            'n_contacts': n_contact_points_per_step}
        return info

    def _render_frame(self, mode):

        if self.window is None and mode == "human":
            pygame.init()
            pygame.display.init()
            self.window = pygame.display.set_mode((self.window_size, self.window_size))
        if self.clock is None and mode == "human":
            self.clock = pygame.time.Clock()

        canvas = pygame.Surface((self.window_size, self.window_size))
        canvas.fill((255, 255, 255))
        self.screen = canvas

        draw_options = DrawOptions(canvas)

        # Draw goal pose.
        goal_body = self._get_goal_pose_body(self.goal_pose)
        for shape in self.block.shapes:
            goal_points = [pymunk.pygame_util.to_pygame(goal_body.local_to_world(v), draw_options.surface) for v in shape.get_vertices()]
            goal_points += [goal_points[0]]
            pygame.draw.polygon(canvas, self.goal_color, goal_points)

        # Draw agent and block.
        self.space.debug_draw(draw_options)

        if mode == "human":
            # The following line copies our drawings from `canvas` to the visible window
            self.window.blit(canvas, canvas.get_rect())
            pygame.event.pump()
            pygame.display.update()

            # the clock is aleady ticked during in step for "human"


        img = np.transpose(
                np.array(pygame.surfarray.pixels3d(canvas)), axes=(1, 0, 2)
            )
        img = cv2.resize(img, (self.render_size, self.render_size))
        if self.render_action:
            if self.render_action and (self.latest_action is not None):
                action = np.array(self.latest_action)
                coord = (action / 512 * 96).astype(np.int32)
                marker_size = int(8/96*self.render_size)
                thickness = int(1/96*self.render_size)
                cv2.drawMarker(img, coord,
                    color=(255,0,0), markerType=cv2.MARKER_CROSS,
                    markerSize=marker_size, thickness=thickness)
        return img


    def close(self):
        if self.window is not None:
            pygame.display.quit()
            pygame.quit()

    def seed(self, seed=None):
        if seed is None:
            seed = np.random.randint(0,25536)
        self._seed = seed
        self.np_random = np.random.default_rng(seed)

    def _handle_collision(self, arbiter, space, data):
        self.n_contact_points += len(arbiter.contact_point_set.points)

    def _set_state(self, state):
        if isinstance(state, np.ndarray):
            state = state.tolist()
        pos_agent = state[:2]
        pos_block = state[2:4]
        rot_block = state[4]
        self.agent.position = pos_agent
        # setting angle rotates with respect to center of mass
        # therefore will modify the geometric position
        # if not the same as CoM
        # therefore should be modified first.
        if self.legacy:
            # for compatiblity with legacy data
            self.block.position = pos_block
            self.block.angle = rot_block
        else:
            self.block.angle = rot_block
            self.block.position = pos_block

        # Run physics to take effect
        self.space.step(1.0 / self.sim_hz)

    def _set_state_local(self, state_local):
        agent_pos_local = state_local[:2]
        block_pose_local = state_local[2:]
        tf_img_obj = st.AffineTransform(
            translation=self.goal_pose[:2],
            rotation=self.goal_pose[2])
        tf_obj_new = st.AffineTransform(
            translation=block_pose_local[:2],
            rotation=block_pose_local[2]
        )
        tf_img_new = st.AffineTransform(
            matrix=tf_img_obj.params @ tf_obj_new.params
        )
        agent_pos_new = tf_img_new(agent_pos_local)
        new_state = np.array(
            list(agent_pos_new[0]) + list(tf_img_new.translation) \
                + [tf_img_new.rotation])
        self._set_state(new_state)
        return new_state

    def _setup(self):
        self.space = pymunk.Space()
        self.space.gravity = 0, 0
        self.space.damping = 0
        self.teleop = False
        self.render_buffer = list()

        # Add walls.
        walls = [
            self._add_segment((5, 506), (5, 5), 2),
            self._add_segment((5, 5), (506, 5), 2),
            self._add_segment((506, 5), (506, 506), 2),
            self._add_segment((5, 506), (506, 506), 2)
        ]
        self.space.add(*walls)

        # Add agent, block, and goal zone.
        self.agent = self.add_circle((256, 400), 15)
        self.block = self.add_tee((256, 300), 0)
        self.goal_color = pygame.Color('LightGreen')
        self.goal_pose = np.array([256,256,np.pi/4])  # x, y, theta (in radians)

        # Add collision handeling
        self.collision_handeler = self.space.add_collision_handler(0, 0)
        self.collision_handeler.post_solve = self._handle_collision
        self.n_contact_points = 0

        self.max_score = 50 * 100
        self.success_threshold = 0.95    # 95% coverage.

    def _add_segment(self, a, b, radius):
        shape = pymunk.Segment(self.space.static_body, a, b, radius)
        shape.color = pygame.Color('LightGray')    # https://htmlcolorcodes.com/color-names
        return shape

    def add_circle(self, position, radius):
        body = pymunk.Body(body_type=pymunk.Body.KINEMATIC)
        body.position = position
        body.friction = 1
        shape = pymunk.Circle(body, radius)
        shape.color = pygame.Color('RoyalBlue')
        self.space.add(body, shape)
        return body

    def add_box(self, position, height, width):
        mass = 1
        inertia = pymunk.moment_for_box(mass, (height, width))
        body = pymunk.Body(mass, inertia)
        body.position = position
        shape = pymunk.Poly.create_box(body, (height, width))
        shape.color = pygame.Color('LightSlateGray')
        self.space.add(body, shape)
        return body

    def add_tee(self, position, angle, scale=30, color='LightSlateGray', mask=pymunk.ShapeFilter.ALL_MASKS()):
        mass = 1
        length = 4
        vertices1 = [(-length*scale/2, scale),
                                 ( length*scale/2, scale),
                                 ( length*scale/2, 0),
                                 (-length*scale/2, 0)]
        inertia1 = pymunk.moment_for_poly(mass, vertices=vertices1)
        vertices2 = [(-scale/2, scale),
                                 (-scale/2, length*scale),
                                 ( scale/2, length*scale),
                                 ( scale/2, scale)]
        inertia2 = pymunk.moment_for_poly(mass, vertices=vertices1)
        body = pymunk.Body(mass, inertia1 + inertia2)
        shape1 = pymunk.Poly(body, vertices1)
        shape2 = pymunk.Poly(body, vertices2)
        shape1.color = pygame.Color(color)
        shape2.color = pygame.Color(color)
        shape1.filter = pymunk.ShapeFilter(mask=mask)
        shape2.filter = pymunk.ShapeFilter(mask=mask)
        body.center_of_gravity = (shape1.center_of_gravity + shape2.center_of_gravity) / 2
        body.position = position
        body.angle = angle
        body.friction = 1
        self.space.add(body, shape1, shape2)
        return body


class PushTImageEnv(PushTEnv):
    metadata = {"render.modes": ["rgb_array"], "video.frames_per_second": 10}

    def __init__(self,
            legacy=False,
            block_cog=None,
            damping=None,
            render_size=96):
        super().__init__(
            legacy=legacy,
            block_cog=block_cog,
            damping=damping,
            render_size=render_size,
            render_action=False)
        ws = self.window_size
        self.observation_space = spaces.Dict({
            'image': spaces.Box(
                low=0,
                high=1,
                shape=(3,render_size,render_size),
                dtype=np.float32
            ),
            'agent_pos': spaces.Box(
                low=0,
                high=ws,
                shape=(2,),
                dtype=np.float32
            )
        })
        self.render_cache = None

    def _get_obs(self):
        img = super()._render_frame(mode='rgb_array')

        agent_pos = np.array(self.agent.position)
        img_obs = np.moveaxis(img.astype(np.float32) / 255, -1, 0)
        obs = {
            'image': img_obs,
            'agent_pos': agent_pos
        }

        # draw action
        if self.latest_action is not None:
            action = np.array(self.latest_action)
            coord = (action / 512 * 96).astype(np.int32)
            marker_size = int(8/96*self.render_size)
            thickness = int(1/96*self.render_size)
            cv2.drawMarker(img, coord,
                color=(255,0,0), markerType=cv2.MARKER_CROSS,
                markerSize=marker_size, thickness=thickness)
        self.render_cache = img

        return obs

    def render(self, mode):
        assert mode == 'rgb_array'

        if self.render_cache is None:
            self._get_obs()

        return self.render_cache

# %%
import numpy as np

def create_sample_indices(episode_ends, sequence_length, pad_before=0, pad_after=0):
    indices = []
    for i in range(len(episode_ends)):
        start_idx = 0 if i == 0 else episode_ends[i-1]
        end_idx = episode_ends[i]
        episode_length = end_idx - start_idx
        if episode_length < 1:
            continue
        min_start = -pad_before
        max_start = episode_length - sequence_length + pad_after
        for idx in range(min_start, max_start + 1):
            buffer_start_idx = max(idx, 0) + start_idx
            buffer_end_idx = min(idx + sequence_length, episode_length) + start_idx
            if buffer_end_idx <= buffer_start_idx:
                continue
            start_offset = buffer_start_idx - (idx + start_idx)
            end_offset = (idx + sequence_length + start_idx) - buffer_end_idx
            sample_start_idx = start_offset
            sample_end_idx = sequence_length - end_offset
            # Debug print
            print(f"Episode {i}, idx={idx}: buffer_start_idx={buffer_start_idx}, buffer_end_idx={buffer_end_idx}, seq_length={buffer_end_idx-buffer_start_idx}, sample_start_idx={sample_start_idx}, sample_end_idx={sample_end_idx}")
            indices.append([buffer_start_idx, buffer_end_idx, sample_start_idx, sample_end_idx])
    return np.array(indices)

def sample_sequence(train_data, sequence_length, buffer_start_idx, buffer_end_idx, sample_start_idx, sample_end_idx):
    result = {}
    for key, data in train_data.items():
        seq = data
        output_shape = (sequence_length,) + data.shape[1:]
        output = np.zeros(output_shape, dtype=data.dtype)
        if len(seq) == 0:
            print(f"Error: Empty sequence for key {key} at buffer_start_idx={buffer_start_idx}, buffer_end_idx={buffer_end_idx}")
            raise ValueError(f"Empty sequence for {key} should have been skipped")
        slice_length = sample_end_idx - sample_start_idx
        if len(seq) < slice_length:
            padding = np.repeat(seq[-1:], slice_length - len(seq), axis=0)
            seq = np.concatenate([seq, padding], axis=0)
        elif len(seq) > slice_length:
            seq = seq[:slice_length]
        output[sample_start_idx:sample_end_idx] = seq
        if sample_start_idx > 0:
            output[:sample_start_idx] = seq[0]
        if sample_end_idx < sequence_length:
            output[sample_end_idx:] = seq[-1]
        result[key] = output
    return result

def get_data_stats(data):
    data = data.reshape(-1, data.shape[-1])
    return {'min': np.min(data, axis=0), 'max': np.max(data, axis=0)}

def normalize_data(data, stats):
    return (data - stats['min']) / (stats['max'] - stats['min'] + 1e-6) * 2 - 1

def unnormalize_data(data, stats):
    return (data + 1) / 2 * (stats['max'] - stats['min'] + 1e-6) + stats['min']

# %%
# push t image dataset class definition
import torch
import zarr
import numpy as np

class PushTImageDataset(torch.utils.data.Dataset):
    def __init__(self, dataset_path, pred_horizon, obs_horizon, action_horizon):
        self.pred_horizon = pred_horizon
        self.obs_horizon = obs_horizon
        self.action_horizon = action_horizon

        # Open zarr file
        self.dataset_root = zarr.open(dataset_path, 'r')
        self.episode_ends = self.dataset_root['meta']['episode_ends'][:]

        # Validate episode ends
        if len(self.episode_ends) == 0 or np.any(self.episode_ends <= 0):
            raise ValueError("Invalid episode_ends in dataset")

        # Compute statistics for normalization
        agent_pos = self.dataset_root['data']['state'][:, :2]
        action = self.dataset_root['data']['action'][:]
        self.stats = {
            'agent_pos': get_data_stats(agent_pos),
            'action': get_data_stats(action)
        }

        # Create sample indices
        self.indices = create_sample_indices(
            episode_ends=self.episode_ends,
            sequence_length=pred_horizon,
            pad_before=obs_horizon-1,
            pad_after=action_horizon-1
        )
        if len(self.indices) == 0:
            raise ValueError("No valid sample indices generated. Check episode_ends or horizon parameters.")
        seq_lengths = self.indices[:, 1] - self.indices[:, 0]
        if np.any(seq_lengths <= 0):
            raise ValueError(f"Invalid sequence lengths: {seq_lengths[seq_lengths <= 0]}")

    def __len__(self):
        return len(self.indices)

    def __getitem__(self, idx):
      buffer_start_idx, buffer_end_idx, sample_start_idx, sample_end_idx = self.indices[idx]

      # Load raw data from zarr
      train_data = {
          'image': self.dataset_root['data']['img'][buffer_start_idx:buffer_end_idx] / 255.0,
          'agent_pos': self.dataset_root['data']['state'][buffer_start_idx:buffer_end_idx, :2],
          'action': self.dataset_root['data']['action'][buffer_start_idx:buffer_end_idx]
      }

      # Debug: Print raw sequence lengths
      print(f"Index {idx}: raw sequence lengths - image: {len(train_data['image'])}, agent_pos: {len(train_data['agent_pos'])}, action: {len(train_data['action'])}")

      # Check for empty or invalid sequences
      expected_seq_length = buffer_end_idx - buffer_start_idx
      if (len(train_data['image']) != expected_seq_length or
          len(train_data['agent_pos']) != expected_seq_length or
          len(train_data['action']) != expected_seq_length or
          len(train_data['image']) == 0):
          print(f"Skipping invalid sequence at idx={idx}, buffer_start_idx={buffer_start_idx}, buffer_end_idx={buffer_end_idx}, expected_length={expected_seq_length}")
          return self.__getitem__((idx + 1) % len(self.indices))  # Try next index

      # Transpose image to (sequence_length, 3, 96, 96)
      train_data['image'] = np.moveaxis(train_data['image'], -1, 1)

      # Normalize agent_pos and action
      train_data['agent_pos'] = normalize_data(train_data['agent_pos'], self.stats['agent_pos'])
      train_data['action'] = normalize_data(train_data['action'], self.stats['action'])

      # Sample sequence
      sample = sample_sequence(
          train_data=train_data,
          sequence_length=self.pred_horizon,
          buffer_start_idx=0,  # Data is already sliced
          buffer_end_idx=len(train_data['action']),  # Use actual length
          sample_start_idx=sample_start_idx,
          sample_end_idx=sample_end_idx
      )

      # Debug: Print sample keys and shapes
      print(f"Index {idx}: sample keys: {list(sample.keys())}")
      for key, value in sample.items():
          print(f"  {key} shape: {value.shape}")

      # Return only the required observations and actions
      return {
          'image': torch.tensor(sample['image'][:self.obs_horizon], dtype=torch.float32),
          'agent_pos': torch.tensor(sample['agent_pos'][:self.obs_horizon], dtype=torch.float32),
          'action': torch.tensor(sample['action'], dtype=torch.float32)
      }

# %%
import torch
from torch.utils.data import DataLoader
import zarr
import numpy as np

# Dataset path
dataset_path = 'pusht_cchi_v7_replay.zarr.zip'  # Update to 'pusht_zarr' if unzipped
pred_horizon = 16
obs_horizon = 2
action_horizon = 8
dataset = PushTImageDataset(
    dataset_path=dataset_path,
    pred_horizon=pred_horizon,
    obs_horizon=obs_horizon,
    action_horizon=action_horizon
)
dataloader = DataLoader(
    dataset,
    batch_size=32,
    num_workers=0,  # Set to 0 to avoid concurrent zip access issues
    shuffle=True,
    pin_memory=True
)
try:
    print(f"Number of batches: {len(dataloader)}")
    for i, batch in enumerate(dataloader):
        print(f"Batch {i}:")
        print(f"  batch['image'].shape: {batch['image'].shape}")
        print(f"  batch['agent_pos'].shape: {batch['agent_pos'].shape}")
        print(f"  batch['action'].shape: {batch['action'].shape}")
        if i >= 2:
            break
except Exception as e:
    print(f"Error in dataloader: {e}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Episode 170, idx=48: buffer_start_idx=20890, buffer_end_idx=20906, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=49: buffer_start_idx=20891, buffer_end_idx=20907, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=50: buffer_start_idx=20892, buffer_end_idx=20908, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=51: buffer_start_idx=20893, buffer_end_idx=20909, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=52: buffer_start_idx=20894, buffer_end_idx=20910, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=53: buffer_start_idx=20895, buffer_end_idx=20911, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=54: buffer_start_idx=20896, buffer_end_idx=20912, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=55: buffer_start_idx=20897, buffer_end_idx=20913, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=56: buffer_start_idx=20898, buffer_end_idx=20914, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=57: buffer_start_idx=20899, buffer_end_idx=20915, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=58: buffer_start_idx=20900, buffer_end_idx=20916, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=59: buffer_start_idx=20901, buffer_end_idx=20917, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=60: buffer_start_idx=20902, buffer_end_idx=20918, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=61: buffer_start_idx=20903, buffer_end_idx=20919, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=62: buffer_start_idx=20904, buffer_end_idx=20920, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=63: buffer_start_idx=20905, buffer_end_idx=20921, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=64: buffer_start_idx=20906, buffer_end_idx=20922, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=65: buffer_start_idx=20907, buffer_end_idx=20923, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=66: buffer_start_idx=20908, buffer_end_idx=20924, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=67: buffer_start_idx=20909, buffer_end_idx=20925, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=68: buffer_start_idx=20910, buffer_end_idx=20926, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=69: buffer_start_idx=20911, buffer_end_idx=20927, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=70: buffer_start_idx=20912, buffer_end_idx=20928, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=71: buffer_start_idx=20913, buffer_end_idx=20929, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=72: buffer_start_idx=20914, buffer_end_idx=20930, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=73: buffer_start_idx=20915, buffer_end_idx=20931, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=74: buffer_start_idx=20916, buffer_end_idx=20932, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=75: buffer_start_idx=20917, buffer_end_idx=20933, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=76: buffer_start_idx=20918, buffer_end_idx=20934, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=77: buffer_start_idx=20919, buffer_end_idx=20935, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=78: buffer_start_idx=20920, buffer_end_idx=20936, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=79: buffer_start_idx=20921, buffer_end_idx=20937, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=80: buffer_start_idx=20922, buffer_end_idx=20938, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=81: buffer_start_idx=20923, buffer_end_idx=20939, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=82: buffer_start_idx=20924, buffer_end_idx=20940, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=83: buffer_start_idx=20925, buffer_end_idx=20941, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=84: buffer_start_idx=20926, buffer_end_idx=20942, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=85: buffer_start_idx=20927, buffer_end_idx=20943, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=86: buffer_start_idx=20928, buffer_end_idx=20944, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=87: buffer_start_idx=20929, buffer_end_idx=20945, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=88: buffer_start_idx=20930, buffer_end_idx=20946, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=89: buffer_start_idx=20931, buffer_end_idx=20947, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=90: buffer_start_idx=20932, buffer_end_idx=20948, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=91: buffer_start_idx=20933, buffer_end_idx=20949, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=92: buffer_start_idx=20934, buffer_end_idx=20950, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=93: buffer_start_idx=20935, buffer_end_idx=20951, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=94: buffer_start_idx=20936, buffer_end_idx=20952, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=95: buffer_start_idx=20937, buffer_end_idx=20953, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=96: buffer_start_idx=20938, buffer_end_idx=20954, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=97: buffer_start_idx=20939, buffer_end_idx=20955, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=98: buffer_start_idx=20940, buffer_end_idx=20956, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=99: buffer_start_idx=20941, buffer_end_idx=20957, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=100: buffer_start_idx=20942, buffer_end_idx=20958, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=101: buffer_start_idx=20943, buffer_end_idx=20959, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=102: buffer_start_idx=20944, buffer_end_idx=20960, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=103: buffer_start_idx=20945, buffer_end_idx=20961, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=104: buffer_start_idx=20946, buffer_end_idx=20962, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=105: buffer_start_idx=20947, buffer_end_idx=20963, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=106: buffer_start_idx=20948, buffer_end_idx=20964, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=107: buffer_start_idx=20949, buffer_end_idx=20965, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=108: buffer_start_idx=20950, buffer_end_idx=20966, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=109: buffer_start_idx=20951, buffer_end_idx=20967, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=110: buffer_start_idx=20952, buffer_end_idx=20968, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=111: buffer_start_idx=20953, buffer_end_idx=20969, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=112: buffer_start_idx=20954, buffer_end_idx=20970, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=113: buffer_start_idx=20955, buffer_end_idx=20971, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=114: buffer_start_idx=20956, buffer_end_idx=20972, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 170, idx=115: buffer_start_idx=20957, buffer_end_idx=20972, seq_length=15, sample_start_idx=0, sample_end_idx=15
# Episode 170, idx=116: buffer_start_idx=20958, buffer_end_idx=20972, seq_length=14, sample_start_idx=0, sample_end_idx=14
# Episode 170, idx=117: buffer_start_idx=20959, buffer_end_idx=20972, seq_length=13, sample_start_idx=0, sample_end_idx=13
# Episode 170, idx=118: buffer_start_idx=20960, buffer_end_idx=20972, seq_length=12, sample_start_idx=0, sample_end_idx=12
# Episode 170, idx=119: buffer_start_idx=20961, buffer_end_idx=20972, seq_length=11, sample_start_idx=0, sample_end_idx=11
# Episode 170, idx=120: buffer_start_idx=20962, buffer_end_idx=20972, seq_length=10, sample_start_idx=0, sample_end_idx=10
# Episode 170, idx=121: buffer_start_idx=20963, buffer_end_idx=20972, seq_length=9, sample_start_idx=0, sample_end_idx=9
# Episode 171, idx=-1: buffer_start_idx=20972, buffer_end_idx=20987, seq_length=15, sample_start_idx=1, sample_end_idx=16
# Episode 171, idx=0: buffer_start_idx=20972, buffer_end_idx=20988, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=1: buffer_start_idx=20973, buffer_end_idx=20989, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=2: buffer_start_idx=20974, buffer_end_idx=20990, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=3: buffer_start_idx=20975, buffer_end_idx=20991, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=4: buffer_start_idx=20976, buffer_end_idx=20992, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=5: buffer_start_idx=20977, buffer_end_idx=20993, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=6: buffer_start_idx=20978, buffer_end_idx=20994, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=7: buffer_start_idx=20979, buffer_end_idx=20995, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=8: buffer_start_idx=20980, buffer_end_idx=20996, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=9: buffer_start_idx=20981, buffer_end_idx=20997, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=10: buffer_start_idx=20982, buffer_end_idx=20998, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=11: buffer_start_idx=20983, buffer_end_idx=20999, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=12: buffer_start_idx=20984, buffer_end_idx=21000, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=13: buffer_start_idx=20985, buffer_end_idx=21001, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=14: buffer_start_idx=20986, buffer_end_idx=21002, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=15: buffer_start_idx=20987, buffer_end_idx=21003, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=16: buffer_start_idx=20988, buffer_end_idx=21004, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=17: buffer_start_idx=20989, buffer_end_idx=21005, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=18: buffer_start_idx=20990, buffer_end_idx=21006, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=19: buffer_start_idx=20991, buffer_end_idx=21007, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=20: buffer_start_idx=20992, buffer_end_idx=21008, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=21: buffer_start_idx=20993, buffer_end_idx=21009, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=22: buffer_start_idx=20994, buffer_end_idx=21010, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=23: buffer_start_idx=20995, buffer_end_idx=21011, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=24: buffer_start_idx=20996, buffer_end_idx=21012, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=25: buffer_start_idx=20997, buffer_end_idx=21013, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=26: buffer_start_idx=20998, buffer_end_idx=21014, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=27: buffer_start_idx=20999, buffer_end_idx=21015, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=28: buffer_start_idx=21000, buffer_end_idx=21016, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=29: buffer_start_idx=21001, buffer_end_idx=21017, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=30: buffer_start_idx=21002, buffer_end_idx=21018, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=31: buffer_start_idx=21003, buffer_end_idx=21019, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=32: buffer_start_idx=21004, buffer_end_idx=21020, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=33: buffer_start_idx=21005, buffer_end_idx=21021, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=34: buffer_start_idx=21006, buffer_end_idx=21022, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=35: buffer_start_idx=21007, buffer_end_idx=21023, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=36: buffer_start_idx=21008, buffer_end_idx=21024, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=37: buffer_start_idx=21009, buffer_end_idx=21025, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=38: buffer_start_idx=21010, buffer_end_idx=21026, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=39: buffer_start_idx=21011, buffer_end_idx=21027, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=40: buffer_start_idx=21012, buffer_end_idx=21028, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=41: buffer_start_idx=21013, buffer_end_idx=21029, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=42: buffer_start_idx=21014, buffer_end_idx=21030, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=43: buffer_start_idx=21015, buffer_end_idx=21031, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=44: buffer_start_idx=21016, buffer_end_idx=21032, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=45: buffer_start_idx=21017, buffer_end_idx=21033, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=46: buffer_start_idx=21018, buffer_end_idx=21034, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=47: buffer_start_idx=21019, buffer_end_idx=21035, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=48: buffer_start_idx=21020, buffer_end_idx=21036, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=49: buffer_start_idx=21021, buffer_end_idx=21037, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=50: buffer_start_idx=21022, buffer_end_idx=21038, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=51: buffer_start_idx=21023, buffer_end_idx=21039, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=52: buffer_start_idx=21024, buffer_end_idx=21040, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=53: buffer_start_idx=21025, buffer_end_idx=21041, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=54: buffer_start_idx=21026, buffer_end_idx=21042, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=55: buffer_start_idx=21027, buffer_end_idx=21043, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=56: buffer_start_idx=21028, buffer_end_idx=21044, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=57: buffer_start_idx=21029, buffer_end_idx=21045, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=58: buffer_start_idx=21030, buffer_end_idx=21046, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=59: buffer_start_idx=21031, buffer_end_idx=21047, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=60: buffer_start_idx=21032, buffer_end_idx=21048, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=61: buffer_start_idx=21033, buffer_end_idx=21049, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=62: buffer_start_idx=21034, buffer_end_idx=21050, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=63: buffer_start_idx=21035, buffer_end_idx=21051, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=64: buffer_start_idx=21036, buffer_end_idx=21052, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=65: buffer_start_idx=21037, buffer_end_idx=21053, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=66: buffer_start_idx=21038, buffer_end_idx=21054, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=67: buffer_start_idx=21039, buffer_end_idx=21055, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=68: buffer_start_idx=21040, buffer_end_idx=21056, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=69: buffer_start_idx=21041, buffer_end_idx=21057, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=70: buffer_start_idx=21042, buffer_end_idx=21058, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=71: buffer_start_idx=21043, buffer_end_idx=21059, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=72: buffer_start_idx=21044, buffer_end_idx=21060, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=73: buffer_start_idx=21045, buffer_end_idx=21061, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=74: buffer_start_idx=21046, buffer_end_idx=21062, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=75: buffer_start_idx=21047, buffer_end_idx=21063, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=76: buffer_start_idx=21048, buffer_end_idx=21064, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=77: buffer_start_idx=21049, buffer_end_idx=21065, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=78: buffer_start_idx=21050, buffer_end_idx=21066, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=79: buffer_start_idx=21051, buffer_end_idx=21067, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=80: buffer_start_idx=21052, buffer_end_idx=21068, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=81: buffer_start_idx=21053, buffer_end_idx=21069, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=82: buffer_start_idx=21054, buffer_end_idx=21070, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=83: buffer_start_idx=21055, buffer_end_idx=21071, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=84: buffer_start_idx=21056, buffer_end_idx=21072, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=85: buffer_start_idx=21057, buffer_end_idx=21073, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=86: buffer_start_idx=21058, buffer_end_idx=21074, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=87: buffer_start_idx=21059, buffer_end_idx=21075, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=88: buffer_start_idx=21060, buffer_end_idx=21076, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=89: buffer_start_idx=21061, buffer_end_idx=21077, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=90: buffer_start_idx=21062, buffer_end_idx=21078, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=91: buffer_start_idx=21063, buffer_end_idx=21079, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=92: buffer_start_idx=21064, buffer_end_idx=21080, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=93: buffer_start_idx=21065, buffer_end_idx=21081, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=94: buffer_start_idx=21066, buffer_end_idx=21082, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=95: buffer_start_idx=21067, buffer_end_idx=21083, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=96: buffer_start_idx=21068, buffer_end_idx=21084, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=97: buffer_start_idx=21069, buffer_end_idx=21085, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=98: buffer_start_idx=21070, buffer_end_idx=21086, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=99: buffer_start_idx=21071, buffer_end_idx=21087, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 171, idx=100: buffer_start_idx=21072, buffer_end_idx=21087, seq_length=15, sample_start_idx=0, sample_end_idx=15
# Episode 171, idx=101: buffer_start_idx=21073, buffer_end_idx=21087, seq_length=14, sample_start_idx=0, sample_end_idx=14
# Episode 171, idx=102: buffer_start_idx=21074, buffer_end_idx=21087, seq_length=13, sample_start_idx=0, sample_end_idx=13
# Episode 171, idx=103: buffer_start_idx=21075, buffer_end_idx=21087, seq_length=12, sample_start_idx=0, sample_end_idx=12
# Episode 171, idx=104: buffer_start_idx=21076, buffer_end_idx=21087, seq_length=11, sample_start_idx=0, sample_end_idx=11
# Episode 171, idx=105: buffer_start_idx=21077, buffer_end_idx=21087, seq_length=10, sample_start_idx=0, sample_end_idx=10
# Episode 171, idx=106: buffer_start_idx=21078, buffer_end_idx=21087, seq_length=9, sample_start_idx=0, sample_end_idx=9
# Episode 172, idx=-1: buffer_start_idx=21087, buffer_end_idx=21102, seq_length=15, sample_start_idx=1, sample_end_idx=16
# Episode 172, idx=0: buffer_start_idx=21087, buffer_end_idx=21103, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=1: buffer_start_idx=21088, buffer_end_idx=21104, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=2: buffer_start_idx=21089, buffer_end_idx=21105, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=3: buffer_start_idx=21090, buffer_end_idx=21106, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=4: buffer_start_idx=21091, buffer_end_idx=21107, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=5: buffer_start_idx=21092, buffer_end_idx=21108, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=6: buffer_start_idx=21093, buffer_end_idx=21109, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=7: buffer_start_idx=21094, buffer_end_idx=21110, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=8: buffer_start_idx=21095, buffer_end_idx=21111, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=9: buffer_start_idx=21096, buffer_end_idx=21112, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=10: buffer_start_idx=21097, buffer_end_idx=21113, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=11: buffer_start_idx=21098, buffer_end_idx=21114, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=12: buffer_start_idx=21099, buffer_end_idx=21115, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=13: buffer_start_idx=21100, buffer_end_idx=21116, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=14: buffer_start_idx=21101, buffer_end_idx=21117, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=15: buffer_start_idx=21102, buffer_end_idx=21118, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=16: buffer_start_idx=21103, buffer_end_idx=21119, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=17: buffer_start_idx=21104, buffer_end_idx=21120, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=18: buffer_start_idx=21105, buffer_end_idx=21121, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=19: buffer_start_idx=21106, buffer_end_idx=21122, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=20: buffer_start_idx=21107, buffer_end_idx=21123, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=21: buffer_start_idx=21108, buffer_end_idx=21124, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=22: buffer_start_idx=21109, buffer_end_idx=21125, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=23: buffer_start_idx=21110, buffer_end_idx=21126, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=24: buffer_start_idx=21111, buffer_end_idx=21127, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=25: buffer_start_idx=21112, buffer_end_idx=21128, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=26: buffer_start_idx=21113, buffer_end_idx=21129, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=27: buffer_start_idx=21114, buffer_end_idx=21130, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=28: buffer_start_idx=21115, buffer_end_idx=21131, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=29: buffer_start_idx=21116, buffer_end_idx=21132, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=30: buffer_start_idx=21117, buffer_end_idx=21133, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=31: buffer_start_idx=21118, buffer_end_idx=21134, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=32: buffer_start_idx=21119, buffer_end_idx=21135, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=33: buffer_start_idx=21120, buffer_end_idx=21136, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=34: buffer_start_idx=21121, buffer_end_idx=21137, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=35: buffer_start_idx=21122, buffer_end_idx=21138, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=36: buffer_start_idx=21123, buffer_end_idx=21139, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=37: buffer_start_idx=21124, buffer_end_idx=21140, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=38: buffer_start_idx=21125, buffer_end_idx=21141, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=39: buffer_start_idx=21126, buffer_end_idx=21142, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=40: buffer_start_idx=21127, buffer_end_idx=21143, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=41: buffer_start_idx=21128, buffer_end_idx=21144, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=42: buffer_start_idx=21129, buffer_end_idx=21145, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=43: buffer_start_idx=21130, buffer_end_idx=21146, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=44: buffer_start_idx=21131, buffer_end_idx=21147, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=45: buffer_start_idx=21132, buffer_end_idx=21148, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=46: buffer_start_idx=21133, buffer_end_idx=21149, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=47: buffer_start_idx=21134, buffer_end_idx=21150, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=48: buffer_start_idx=21135, buffer_end_idx=21151, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=49: buffer_start_idx=21136, buffer_end_idx=21152, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=50: buffer_start_idx=21137, buffer_end_idx=21153, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=51: buffer_start_idx=21138, buffer_end_idx=21154, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=52: buffer_start_idx=21139, buffer_end_idx=21155, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=53: buffer_start_idx=21140, buffer_end_idx=21156, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=54: buffer_start_idx=21141, buffer_end_idx=21157, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=55: buffer_start_idx=21142, buffer_end_idx=21158, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=56: buffer_start_idx=21143, buffer_end_idx=21159, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=57: buffer_start_idx=21144, buffer_end_idx=21160, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=58: buffer_start_idx=21145, buffer_end_idx=21161, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=59: buffer_start_idx=21146, buffer_end_idx=21162, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=60: buffer_start_idx=21147, buffer_end_idx=21163, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=61: buffer_start_idx=21148, buffer_end_idx=21164, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=62: buffer_start_idx=21149, buffer_end_idx=21165, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 172, idx=63: buffer_start_idx=21150, buffer_end_idx=21165, seq_length=15, sample_start_idx=0, sample_end_idx=15
# Episode 172, idx=64: buffer_start_idx=21151, buffer_end_idx=21165, seq_length=14, sample_start_idx=0, sample_end_idx=14
# Episode 172, idx=65: buffer_start_idx=21152, buffer_end_idx=21165, seq_length=13, sample_start_idx=0, sample_end_idx=13
# Episode 172, idx=66: buffer_start_idx=21153, buffer_end_idx=21165, seq_length=12, sample_start_idx=0, sample_end_idx=12
# Episode 172, idx=67: buffer_start_idx=21154, buffer_end_idx=21165, seq_length=11, sample_start_idx=0, sample_end_idx=11
# Episode 172, idx=68: buffer_start_idx=21155, buffer_end_idx=21165, seq_length=10, sample_start_idx=0, sample_end_idx=10
# Episode 172, idx=69: buffer_start_idx=21156, buffer_end_idx=21165, seq_length=9, sample_start_idx=0, sample_end_idx=9
# Episode 173, idx=-1: buffer_start_idx=21165, buffer_end_idx=21180, seq_length=15, sample_start_idx=1, sample_end_idx=16
# Episode 173, idx=0: buffer_start_idx=21165, buffer_end_idx=21181, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=1: buffer_start_idx=21166, buffer_end_idx=21182, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=2: buffer_start_idx=21167, buffer_end_idx=21183, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=3: buffer_start_idx=21168, buffer_end_idx=21184, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=4: buffer_start_idx=21169, buffer_end_idx=21185, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=5: buffer_start_idx=21170, buffer_end_idx=21186, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=6: buffer_start_idx=21171, buffer_end_idx=21187, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=7: buffer_start_idx=21172, buffer_end_idx=21188, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=8: buffer_start_idx=21173, buffer_end_idx=21189, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=9: buffer_start_idx=21174, buffer_end_idx=21190, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=10: buffer_start_idx=21175, buffer_end_idx=21191, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=11: buffer_start_idx=21176, buffer_end_idx=21192, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=12: buffer_start_idx=21177, buffer_end_idx=21193, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=13: buffer_start_idx=21178, buffer_end_idx=21194, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=14: buffer_start_idx=21179, buffer_end_idx=21195, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=15: buffer_start_idx=21180, buffer_end_idx=21196, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=16: buffer_start_idx=21181, buffer_end_idx=21197, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=17: buffer_start_idx=21182, buffer_end_idx=21198, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=18: buffer_start_idx=21183, buffer_end_idx=21199, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=19: buffer_start_idx=21184, buffer_end_idx=21200, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=20: buffer_start_idx=21185, buffer_end_idx=21201, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=21: buffer_start_idx=21186, buffer_end_idx=21202, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=22: buffer_start_idx=21187, buffer_end_idx=21203, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=23: buffer_start_idx=21188, buffer_end_idx=21204, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=24: buffer_start_idx=21189, buffer_end_idx=21205, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=25: buffer_start_idx=21190, buffer_end_idx=21206, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=26: buffer_start_idx=21191, buffer_end_idx=21207, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=27: buffer_start_idx=21192, buffer_end_idx=21208, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=28: buffer_start_idx=21193, buffer_end_idx=21209, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=29: buffer_start_idx=21194, buffer_end_idx=21210, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=30: buffer_start_idx=21195, buffer_end_idx=21211, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=31: buffer_start_idx=21196, buffer_end_idx=21212, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=32: buffer_start_idx=21197, buffer_end_idx=21213, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=33: buffer_start_idx=21198, buffer_end_idx=21214, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=34: buffer_start_idx=21199, buffer_end_idx=21215, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=35: buffer_start_idx=21200, buffer_end_idx=21216, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=36: buffer_start_idx=21201, buffer_end_idx=21217, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=37: buffer_start_idx=21202, buffer_end_idx=21218, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=38: buffer_start_idx=21203, buffer_end_idx=21219, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=39: buffer_start_idx=21204, buffer_end_idx=21220, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=40: buffer_start_idx=21205, buffer_end_idx=21221, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=41: buffer_start_idx=21206, buffer_end_idx=21222, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=42: buffer_start_idx=21207, buffer_end_idx=21223, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=43: buffer_start_idx=21208, buffer_end_idx=21224, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=44: buffer_start_idx=21209, buffer_end_idx=21225, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=45: buffer_start_idx=21210, buffer_end_idx=21226, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=46: buffer_start_idx=21211, buffer_end_idx=21227, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=47: buffer_start_idx=21212, buffer_end_idx=21228, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=48: buffer_start_idx=21213, buffer_end_idx=21229, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=49: buffer_start_idx=21214, buffer_end_idx=21230, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=50: buffer_start_idx=21215, buffer_end_idx=21231, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=51: buffer_start_idx=21216, buffer_end_idx=21232, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=52: buffer_start_idx=21217, buffer_end_idx=21233, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=53: buffer_start_idx=21218, buffer_end_idx=21234, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=54: buffer_start_idx=21219, buffer_end_idx=21235, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=55: buffer_start_idx=21220, buffer_end_idx=21236, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=56: buffer_start_idx=21221, buffer_end_idx=21237, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=57: buffer_start_idx=21222, buffer_end_idx=21238, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=58: buffer_start_idx=21223, buffer_end_idx=21239, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=59: buffer_start_idx=21224, buffer_end_idx=21240, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=60: buffer_start_idx=21225, buffer_end_idx=21241, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=61: buffer_start_idx=21226, buffer_end_idx=21242, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=62: buffer_start_idx=21227, buffer_end_idx=21243, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=63: buffer_start_idx=21228, buffer_end_idx=21244, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=64: buffer_start_idx=21229, buffer_end_idx=21245, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=65: buffer_start_idx=21230, buffer_end_idx=21246, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=66: buffer_start_idx=21231, buffer_end_idx=21247, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=67: buffer_start_idx=21232, buffer_end_idx=21248, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=68: buffer_start_idx=21233, buffer_end_idx=21249, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=69: buffer_start_idx=21234, buffer_end_idx=21250, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=70: buffer_start_idx=21235, buffer_end_idx=21251, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=71: buffer_start_idx=21236, buffer_end_idx=21252, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=72: buffer_start_idx=21237, buffer_end_idx=21253, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=73: buffer_start_idx=21238, buffer_end_idx=21254, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=74: buffer_start_idx=21239, buffer_end_idx=21255, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=75: buffer_start_idx=21240, buffer_end_idx=21256, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=76: buffer_start_idx=21241, buffer_end_idx=21257, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=77: buffer_start_idx=21242, buffer_end_idx=21258, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=78: buffer_start_idx=21243, buffer_end_idx=21259, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=79: buffer_start_idx=21244, buffer_end_idx=21260, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=80: buffer_start_idx=21245, buffer_end_idx=21261, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=81: buffer_start_idx=21246, buffer_end_idx=21262, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=82: buffer_start_idx=21247, buffer_end_idx=21263, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=83: buffer_start_idx=21248, buffer_end_idx=21264, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=84: buffer_start_idx=21249, buffer_end_idx=21265, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=85: buffer_start_idx=21250, buffer_end_idx=21266, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=86: buffer_start_idx=21251, buffer_end_idx=21267, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=87: buffer_start_idx=21252, buffer_end_idx=21268, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=88: buffer_start_idx=21253, buffer_end_idx=21269, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=89: buffer_start_idx=21254, buffer_end_idx=21270, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=90: buffer_start_idx=21255, buffer_end_idx=21271, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=91: buffer_start_idx=21256, buffer_end_idx=21272, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=92: buffer_start_idx=21257, buffer_end_idx=21273, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=93: buffer_start_idx=21258, buffer_end_idx=21274, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=94: buffer_start_idx=21259, buffer_end_idx=21275, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=95: buffer_start_idx=21260, buffer_end_idx=21276, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=96: buffer_start_idx=21261, buffer_end_idx=21277, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=97: buffer_start_idx=21262, buffer_end_idx=21278, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=98: buffer_start_idx=21263, buffer_end_idx=21279, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=99: buffer_start_idx=21264, buffer_end_idx=21280, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=100: buffer_start_idx=21265, buffer_end_idx=21281, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=101: buffer_start_idx=21266, buffer_end_idx=21282, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=102: buffer_start_idx=21267, buffer_end_idx=21283, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=103: buffer_start_idx=21268, buffer_end_idx=21284, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=104: buffer_start_idx=21269, buffer_end_idx=21285, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=105: buffer_start_idx=21270, buffer_end_idx=21286, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=106: buffer_start_idx=21271, buffer_end_idx=21287, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=107: buffer_start_idx=21272, buffer_end_idx=21288, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=108: buffer_start_idx=21273, buffer_end_idx=21289, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=109: buffer_start_idx=21274, buffer_end_idx=21290, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=110: buffer_start_idx=21275, buffer_end_idx=21291, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=111: buffer_start_idx=21276, buffer_end_idx=21292, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=112: buffer_start_idx=21277, buffer_end_idx=21293, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=113: buffer_start_idx=21278, buffer_end_idx=21294, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=114: buffer_start_idx=21279, buffer_end_idx=21295, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=115: buffer_start_idx=21280, buffer_end_idx=21296, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 173, idx=116: buffer_start_idx=21281, buffer_end_idx=21296, seq_length=15, sample_start_idx=0, sample_end_idx=15
# Episode 173, idx=117: buffer_start_idx=21282, buffer_end_idx=21296, seq_length=14, sample_start_idx=0, sample_end_idx=14
# Episode 173, idx=118: buffer_start_idx=21283, buffer_end_idx=21296, seq_length=13, sample_start_idx=0, sample_end_idx=13
# Episode 173, idx=119: buffer_start_idx=21284, buffer_end_idx=21296, seq_length=12, sample_start_idx=0, sample_end_idx=12
# Episode 173, idx=120: buffer_start_idx=21285, buffer_end_idx=21296, seq_length=11, sample_start_idx=0, sample_end_idx=11
# Episode 173, idx=121: buffer_start_idx=21286, buffer_end_idx=21296, seq_length=10, sample_start_idx=0, sample_end_idx=10
# Episode 173, idx=122: buffer_start_idx=21287, buffer_end_idx=21296, seq_length=9, sample_start_idx=0, sample_end_idx=9
# Episode 174, idx=-1: buffer_start_idx=21296, buffer_end_idx=21311, seq_length=15, sample_start_idx=1, sample_end_idx=16
# Episode 174, idx=0: buffer_start_idx=21296, buffer_end_idx=21312, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 174, idx=1: buffer_start_idx=21297, buffer_end_idx=21313, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 174, idx=2: buffer_start_idx=21298, buffer_end_idx=21314, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 174, idx=3: buffer_start_idx=21299, buffer_end_idx=21315, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 174, idx=4: buffer_start_idx=21300, buffer_end_idx=21316, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 174, idx=5: buffer_start_idx=21301, buffer_end_idx=21317, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 174, idx=6: buffer_start_idx=21302, buffer_end_idx=21318, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 174, idx=7: buffer_start_idx=21303, buffer_end_idx=21319, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 174, idx=8: buffer_start_idx=21304, buffer_end_idx=21320, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 174, idx=9: buffer_start_idx=21305, buffer_end_idx=21321, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 174, idx=10: buffer_start_idx=21306, buffer_end_idx=21322, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 174, idx=11: buffer_start_idx=21307, buffer_end_idx=21323, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 174, idx=12: buffer_start_idx=21308, buffer_end_idx=21324, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 174, idx=13: buffer_start_idx=21309, buffer_end_idx=21325, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 174, idx=14: buffer_start_idx=21310, buffer_end_idx=21326, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 174, idx=15: buffer_start_idx=21311, buffer_end_idx=21327, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 174, idx=16: buffer_start_idx=21312, buffer_end_idx=21328, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 174, idx=17: buffer_start_idx=21313, buffer_end_idx=21329, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 174, idx=18: buffer_start_idx=21314, buffer_end_idx=21330, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 174, idx=19: buffer_start_idx=21315, buffer_end_idx=21331, seq_length=16, sample_start_idx=0, sample_end_idx=16
# Episode 174, idx=20: buffer_start_idx=21316, buffer_end_idx=21332, seq_length=16, sample_start_idx=0, sample_end_idx=16
# ...
# Index 16481: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 18401: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 18401: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 19316: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 19316: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 14833: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 14833: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 14722: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 14722: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 7108: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 7108: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 11372: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 11372: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 10447: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 10447: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 12397: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 12397: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Batch 0:
#   batch['image'].shape: torch.Size([32, 2, 3, 96, 96])
#   batch['agent_pos'].shape: torch.Size([32, 2, 2])
#   batch['action'].shape: torch.Size([32, 16, 2])
# Index 17396: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 17396: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 2015: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 2015: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 1212: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 1212: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 10729: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 10729: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 17073: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 17073: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 20605: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 20605: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 16332: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 16332: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 13503: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 13503: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 23252: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 23252: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 17874: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 17874: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 20309: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 20309: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 2045: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 2045: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 18407: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 18407: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 10755: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 10755: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 4758: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 4758: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 6313: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 6313: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 1982: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 1982: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 8144: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 8144: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 22263: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 22263: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 15407: raw sequence lengths - image: 9, agent_pos: 9, action: 9
# Index 15407: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 8072: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 8072: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 5052: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 5052: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 15133: raw sequence lengths - image: 11, agent_pos: 11, action: 11
# Index 15133: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 18692: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 18692: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 23499: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 23499: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 9231: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 9231: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 3319: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 3319: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 18648: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 18648: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 10557: raw sequence lengths - image: 12, agent_pos: 12, action: 12
# Index 10557: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 19451: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 19451: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 8521: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 8521: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 2661: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 2661: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Batch 1:
#   batch['image'].shape: torch.Size([32, 2, 3, 96, 96])
#   batch['agent_pos'].shape: torch.Size([32, 2, 2])
#   batch['action'].shape: torch.Size([32, 16, 2])
# Index 21146: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 21146: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 6872: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 6872: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 10214: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 10214: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 8233: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 8233: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 14276: raw sequence lengths - image: 11, agent_pos: 11, action: 11
# Index 14276: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 14285: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 14285: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 11408: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 11408: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 23190: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 23190: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 8062: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 8062: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 4343: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 4343: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 15907: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 15907: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 9265: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 9265: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 20263: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 20263: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 14553: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 14553: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 12099: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 12099: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 9526: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 9526: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 8956: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 8956: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 24072: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 24072: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 6343: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 6343: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 10603: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 10603: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 10881: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 10881: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 2251: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 2251: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 12131: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 12131: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 12330: raw sequence lengths - image: 15, agent_pos: 15, action: 15
# Index 12330: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 6793: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 6793: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 311: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 311: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 14215: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 14215: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 4035: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 4035: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 3093: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 3093: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 23274: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 23274: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 202: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 202: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 9061: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 9061: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Batch 2:
#   batch['image'].shape: torch.Size([32, 2, 3, 96, 96])
#   batch['agent_pos'].shape: torch.Size([32, 2, 2])
#   batch['action'].shape: torch.Size([32, 16, 2])

# %%
dataset_path = "pusht_cchi_v7_replay.zarr.zip"
dataset_root = zarr.open(dataset_path, 'r')
print("Dataset keys:", list(dataset_root.keys()))
print("Data keys:", list(dataset_root['data'].keys()))
print("Meta keys:", list(dataset_root['meta'].keys()))
print("Episode ends shape:", dataset_root['meta']['episode_ends'].shape)
print("Action shape:", dataset_root['data']['action'].shape)
print("State shape:", dataset_root['data']['state'].shape)
print("Image shape:", dataset_root['data']['img'].shape)
episode_ends = dataset_root['meta']['episode_ends'][:]
episode_starts = np.concatenate([[0], episode_ends[:-1]])
episode_lengths = episode_ends - episode_starts
print(f"Episode lengths: min={episode_lengths.min()}, max={episode_lengths.max()}, mean={episode_lengths.mean()}")
if np.any(episode_lengths <= 0):
    print(f"Warning: Found {np.sum(episode_lengths <= 0)} episodes with length <= 0")
# Out:
# Dataset keys: ['data', 'meta']
# Data keys: ['action', 'img', 'keypoint', 'n_contacts', 'state']
# Meta keys: ['episode_ends']
# Episode ends shape: (206,)
# Action shape: (25650, 2)
# State shape: (25650, 5)
# Image shape: (25650, 96, 96, 3)
# Episode lengths: min=49, max=246, mean=124.51456310679612

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F

class SinusoidalPosEmb(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.dim = dim
    def forward(self, x):
        device = x.device
        half_dim = self.dim // 2
        emb = math.log(10000) / (half_dim - 1)
        emb = torch.exp(torch.arange(half_dim, device=device) * -emb)
        emb = x[:, None] * emb[None, :]
        emb = torch.cat((emb.sin(), emb.cos()), dim=-1)
        return emb

class Downsample1d(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.conv = nn.Conv1d(dim, dim, 3, 2, 1)
    def forward(self, x):
        return self.conv(x)

class Upsample1d(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.conv = nn.ConvTranspose1d(dim, dim, 4, 2, 1)
    def forward(self, x):
        return self.conv(x)

class Conv1dBlock(nn.Module):
    def __init__(self, inp_channels, out_channels, kernel_size=5, n_groups=8):
        super().__init__()
        self.conv = nn.Conv1d(inp_channels, out_channels, kernel_size, padding=kernel_size//2)
        self.norm = nn.GroupNorm(n_groups, out_channels)
        self.act = nn.SiLU()
        print(f"Conv1dBlock: in_channels={inp_channels}, out_channels={out_channels}")
    def forward(self, x):
        print(f"Conv1dBlock input shape: {x.shape}")
        x = self.conv(x)
        print(f"Conv1dBlock output shape: {x.shape}")
        x = self.norm(x)
        x = self.act(x)
        return x

class ConditionalResidualBlock1D(nn.Module):
    def __init__(self, in_channels, out_channels, cond_dim, kernel_size=5, n_groups=8):
        super().__init__()
        self.blocks = nn.ModuleList([
            Conv1dBlock(in_channels, out_channels, kernel_size, n_groups),
            Conv1dBlock(out_channels, out_channels, kernel_size, n_groups)
        ])
        self.cond_proj = nn.Linear(cond_dim, out_channels) if cond_dim > 0 else None
        self.residual_conv = nn.Conv1d(in_channels, out_channels, 1) if in_channels != out_channels else nn.Identity()
        print(f"ConditionalResidualBlock1D: in_channels={in_channels}, out_channels={out_channels}, cond_dim={cond_dim}")
    def forward(self, x, cond):
        print(f"ConditionalResidualBlock1D input shape: {x.shape}")
        out = self.blocks[0](x)
        if cond is not None:
            cond = self.cond_proj(cond).unsqueeze(-1)
            out = out + cond
        out = self.blocks[1](out)
        out = out + self.residual_conv(x)
        print(f"ConditionalResidualBlock1D output shape: {out.shape}")
        return out

class ConditionalUnet1D(nn.Module):
    def __init__(self, input_dim, global_cond_dim, down_dims=[64, 128, 256]):
        super().__init__()
        all_dims = [input_dim] + down_dims
        self.time_emb = SinusoidalPosEmb(32)
        self.time_mlp = nn.Sequential(nn.Linear(32, 64), nn.SiLU(), nn.Linear(64, down_dims[0]))

        self.down_blocks = nn.ModuleList()
        self.up_blocks = nn.ModuleList()

        # Downsampling blocks
        for i in range(len(all_dims) - 1):
            self.down_blocks.append(
                ConditionalResidualBlock1D(all_dims[i], all_dims[i+1], global_cond_dim + down_dims[0])
            )
            if i < len(all_dims) - 2:  # No downsample on last block
                self.down_blocks.append(Downsample1d(all_dims[i+1]))

        # Middle block
        mid_dim = down_dims[-1]
        self.mid_block = ConditionalResidualBlock1D(mid_dim, mid_dim, global_cond_dim + down_dims[0])

        # Upsampling blocks
        rev_dims = list(reversed(down_dims))  # [256, 128, 64]
        skip_dims = list(reversed(down_dims + [down_dims[-1]]))[:-1]  # [256, 128, 64]
        for i in range(len(down_dims)):
            skip_dim = skip_dims[i]  # [256, 128, 64]
            in_channels = rev_dims[i] + skip_dim  # e.g., 256+256, 128+128, 64+64
            out_channels = rev_dims[i] if i < len(down_dims)-1 else down_dims[0]  # Last block outputs 64
            self.up_blocks.append(
                ConditionalResidualBlock1D(in_channels, out_channels, global_cond_dim + down_dims[0])
            )
            if i < len(down_dims)-1:
                self.up_blocks.append(Upsample1d(out_channels))

        # Final convolution
        self.final_conv = nn.Conv1d(down_dims[0], input_dim, 1)
        print(f"final_conv: in_channels={down_dims[0]}, out_channels={input_dim}")

        print(f"ConditionalUnet1D initialized with in_channels={input_dim}, down_dims={down_dims}, global_cond_dim={global_cond_dim}")

    def forward(self, x, t, global_cond):
        print(f"Unet input shape: {x.shape}, timesteps: {t.shape}, global_cond: {global_cond.shape if global_cond is not None else None}")

        time_emb = self.time_emb(t)
        time_cond = self.time_mlp(time_emb)
        cond = torch.cat([global_cond, time_cond], dim=-1) if global_cond is not None else time_cond

        down_outs = [x]
        for i, block in enumerate(self.down_blocks):
            if isinstance(block, Downsample1d):
                down_outs.append(block(down_outs[-1]))
            else:
                down_outs.append(block(down_outs[-1], cond))
            print(f"Down block {i} output shape: {down_outs[-1].shape}")

        mid_out = self.mid_block(down_outs[-1], cond)
        print(f"Mid block output shape: {mid_out.shape}")

        up_out = mid_out
        for i, block in enumerate(self.up_blocks):
            if isinstance(block, Upsample1d):
                up_out = block(up_out)
                print(f"Upsample {i} output shape: {up_out.shape}")
            else:
                skip_idx = len(down_outs) - 1 - (i // 2) * 2  # [4, 2, 0]
                skip = down_outs[skip_idx]
                print(f"Selecting skip_idx={skip_idx}, skip shape: {skip.shape}")
                if up_out.shape[-1] != skip.shape[-1]:
                    skip = F.interpolate(skip, size=up_out.shape[-1], mode="nearest")
                up_out = torch.cat([up_out, skip], dim=1)
                print(f"Concat shape before up block {i}: {up_out.shape}")
                up_out = block(up_out, cond)
                print(f"Up block {i} output shape: {up_out.shape}")

        print(f"Before final_conv shape: {up_out.shape}")
        final_out = self.final_conv(up_out)
        print(f"Final output shape: {final_out.shape}")
        return final_out

# %%
# define vision encoder helpers
def get_resnet(name):
    return getattr(torchvision.models, name)(pretrained=True)

def replace_submodules(root_module, predicate, func):
    for name, module in root_module.named_children():
        if predicate(module):
            setattr(root_module, name, func(module))
        else:
            replace_submodules(module, predicate, func)
    return root_module

def replace_bn_with_gn(module):
    return nn.GroupNorm(num_groups=32, num_channels=module.num_features)

# %%
# construct and test network
vision_encoder = get_resnet('resnet18')
vision_encoder = replace_submodules(vision_encoder, lambda m: isinstance(m, nn.BatchNorm2d), replace_bn_with_gn)
vision_encoder.fc = nn.Identity()
vision_feature_dim = 512
lowdim_obs_dim = 2
obs_dim = vision_feature_dim + lowdim_obs_dim
action_dim = 2

noise_pred_net = ConditionalUnet1D(
    input_dim=action_dim,
    global_cond_dim=obs_dim * obs_horizon
)

nets = nn.ModuleDict({
    'vision_encoder': vision_encoder,
    'noise_pred_net': noise_pred_net
})
# Out:
# Conv1dBlock: in_channels=2, out_channels=64
# Conv1dBlock: in_channels=64, out_channels=64
# ConditionalResidualBlock1D: in_channels=2, out_channels=64, cond_dim=1092
# Conv1dBlock: in_channels=64, out_channels=128
# Conv1dBlock: in_channels=128, out_channels=128
# ConditionalResidualBlock1D: in_channels=64, out_channels=128, cond_dim=1092
# Conv1dBlock: in_channels=128, out_channels=256
# Conv1dBlock: in_channels=256, out_channels=256
# ConditionalResidualBlock1D: in_channels=128, out_channels=256, cond_dim=1092
# Conv1dBlock: in_channels=256, out_channels=256
# Conv1dBlock: in_channels=256, out_channels=256
# ConditionalResidualBlock1D: in_channels=256, out_channels=256, cond_dim=1092
# Conv1dBlock: in_channels=512, out_channels=256
# Conv1dBlock: in_channels=256, out_channels=256
# ConditionalResidualBlock1D: in_channels=512, out_channels=256, cond_dim=1092
# Conv1dBlock: in_channels=384, out_channels=128
# Conv1dBlock: in_channels=128, out_channels=128
# ConditionalResidualBlock1D: in_channels=384, out_channels=128, cond_dim=1092
# Conv1dBlock: in_channels=192, out_channels=64
# Conv1dBlock: in_channels=64, out_channels=64
# ConditionalResidualBlock1D: in_channels=192, out_channels=64, cond_dim=1092
# final_conv: in_channels=64, out_channels=2
# ConditionalUnet1D initialized with in_channels=2, down_dims=[64, 128, 256], global_cond_dim=1028

# %%
if torch.cuda.is_available():
    print("GPU Memory Allocated:", torch.cuda.memory_allocated() / 1024**2, "MB")
    print("GPU Memory Cached:", torch.cuda.memory_reserved() / 1024**2, "MB")
# Out:
# GPU Memory Allocated: 0.0 MB
# GPU Memory Cached: 72.0 MB

# %%
# define noise scheduler and move to device
from diffusers import DDPMScheduler
import torch

# Define noise scheduler
num_diffusion_iters = 100
noise_scheduler = DDPMScheduler(
    num_train_timesteps=num_diffusion_iters,
    beta_schedule='squaredcos_cap_v2',
    clip_sample=True,
    prediction_type='epsilon'
)

# Set device (prefer GPU, fall back to CPU)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Move network to device
try:
    nets.to(device)
    print("Network moved to device successfully")
except RuntimeError as e:
    print(f"Error moving network to device: {e}")
    if 'CUDA' in str(e):
        print("Falling back to CPU due to CUDA error")
        device = torch.device('cpu')
        nets.to(device)

# Verify network is on the correct device
print(f"Network device: {next(nets.parameters()).device}")
# Out:
# Using device: cuda
# Network moved to device successfully
# Network device: cuda:0

# %%
import time
import matplotlib.pyplot as plt
import torch.nn as nn
from tqdm.auto import tqdm
from torch.optim.lr_scheduler import CosineAnnealingLR
from torch_ema import ExponentialMovingAverage
from torch.cuda.amp import autocast, GradScaler
import os
import numpy as np

# Record start time
start_time = time.time()

# Training configuration
num_epochs = 50  # Total epochs
start_epoch = 0  # Start from 0 unless resuming
checkpoint_path = None  # Set to load checkpoint if resuming

# Check for latest checkpoint
checkpoint_files = [f for f in os.listdir() if f.startswith("checkpoint_epoch_") and f.endswith(".pt")]
if checkpoint_files:
    latest_checkpoint = max(checkpoint_files, key=lambda x: int(x.split("_")[2].split(".")[0]))
    checkpoint_epoch = int(latest_checkpoint.split("_")[2].split(".")[0])
    checkpoint_path = latest_checkpoint
    ema_checkpoint_path = f"ema_{latest_checkpoint}"
    if os.path.exists(ema_checkpoint_path):
        print(f"Found checkpoint: {checkpoint_path} (epoch {checkpoint_epoch})")
        nets.load_state_dict(torch.load(checkpoint_path))
        ema.load_state_dict(torch.load(ema_checkpoint_path))
        start_epoch = checkpoint_epoch
        print(f"Resuming training from epoch {start_epoch + 1}")
    else:
        print(f"EMA checkpoint {ema_checkpoint_path} not found, starting fresh")
        checkpoint_path = None

# Initialize EMA, optimizer, scheduler, and scaler
ema = ExponentialMovingAverage(nets.parameters(), decay=0.75)
optimizer = torch.optim.AdamW(params=nets.parameters(), lr=1e-4, weight_decay=1e-6)
lr_scheduler = CosineAnnealingLR(optimizer, T_max=len(dataloader) * num_epochs, eta_min=0)
scaler = GradScaler()  # For mixed precision training

# Load or initialize loss history
epoch_losses = torch.load("epoch_losses.pt") if os.path.exists("epoch_losses.pt") and checkpoint_path else []

# Print initial GPU memory stats
if torch.cuda.is_available():
    print("Initial GPU Memory Allocated:", torch.cuda.memory_allocated() / 1024**2, "MB")
    print("Initial GPU Memory Cached:", torch.cuda.memory_reserved() / 1024**2, "MB")

# Training loop
with tqdm(range(start_epoch, num_epochs), desc='Epoch') as tglobal:
    for epoch_idx in tglobal:
        epoch_loss = []
        with tqdm(dataloader, desc='Batch', leave=False) as tepoch:
            for nbatch in tepoch:
                nimage = nbatch['image'][:, :obs_horizon].to(device)
                nagent_pos = nbatch['agent_pos'][:, :obs_horizon].to(device)
                naction = nbatch['action'].to(device)
                B = nagent_pos.shape[0]

                # Debug: Print batch shapes
                print(f"Batch shapes: image={nimage.shape}, agent_pos={nagent_pos.shape}, action={naction.shape}")

                # Process observations with mixed precision
                with autocast():
                    image_features = nets['vision_encoder'](nimage.flatten(end_dim=1))
                    image_features = image_features.reshape(*nimage.shape[:2], -1)
                    obs_features = torch.cat([image_features, nagent_pos], dim=-1)
                    obs_cond = obs_features.flatten(start_dim=1)

                    # Add noise to actions
                    noise = torch.randn(naction.shape, device=device)
                    timesteps = torch.randint(0, noise_scheduler.config.num_train_timesteps, (B,), device=device).long()
                    noisy_actions = noise_scheduler.add_noise(naction, noise, timesteps)

                    # Transpose noisy_actions to [B, action_dim, pred_horizon]
                    noisy_actions = noisy_actions.permute(0, 2, 1)

                    # Predict noise
                    noise_pred = nets['noise_pred_net'](noisy_actions, timesteps, global_cond=obs_cond)
                    loss = nn.functional.mse_loss(noise_pred, noise.permute(0, 2, 1))

                # Backprop with mixed precision
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()
                optimizer.zero_grad()
                lr_scheduler.step()
                ema.update()
                epoch_loss.append(loss.item())
                tepoch.set_postfix(loss=loss.item())

        # Compute and log epoch loss
        epoch_losses.append(np.mean(epoch_loss))
        tglobal.set_postfix(loss=np.mean(epoch_loss))

        # Checkpoint every 10 epochs
        if (epoch_idx + 1) % 10 == 0:
            torch.save(nets.state_dict(), f"checkpoint_epoch_{epoch_idx+1}.pt")
            torch.save(ema.state_dict(), f"ema_checkpoint_epoch_{epoch_idx+1}.pt")
            torch.save(epoch_losses, "epoch_losses.pt")  # Save loss history
            print(f"Saved checkpoint at epoch {epoch_idx+1}")

        # Early stopping
        if epoch_idx > 10 and epoch_losses[-1] < 0.05 and abs(epoch_losses[-1] - epoch_losses[-2]) < 1e-4:
            print(f"Early stopping at epoch {epoch_idx+1}: loss={epoch_losses[-1]}")
            break

# Apply EMA parameters
ema_nets = nets
ema.copy_to(ema_nets.parameters())

# Print training duration and final GPU memory stats
end_time = time.time()
print(f"Training time: {(end_time - start_time) / 3600:.2f} hours")

if torch.cuda.is_available():
    print("Final GPU Memory Allocated:", torch.cuda.memory_allocated() / 1024**2, "MB")
    print("Final GPU Memory Cached:", torch.cuda.memory_reserved() / 1024**2, "MB")

# Plot and save loss
plt.plot(epoch_losses)
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.title('Training Loss Over Epochs')
plt.savefig('training_loss.png')
plt.show()
# Out:
# Initial GPU Memory Allocated: 123.6474609375 MB
# Initial GPU Memory Cached: 142.0 MB
# <ipython-input-29-9b8081dbf295>:40: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()  # For mixed precision training
# Epoch:   0%|          | 0/50 [00:00<?, ?it/s]
# Batch:   0%|          | 0/757 [00:00<?, ?it/s]
# Index 18665: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 18665: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 10758: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 10758: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 17504: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 17504: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 14137: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 14137: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 20839: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 20839: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 3920: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 3920: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 10493: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 10493: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 10002: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 10002: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 2176: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 2176: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 2844: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 2844: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 18172: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 18172: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 20903: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 20903: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 2581: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 2581: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 7362: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 7362: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 16939: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 16939: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 23912: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 23912: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 18590: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 18590: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 549: raw sequence lengths - image: 10, agent_pos: 10, action: 10
# Index 549: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 11014: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 11014: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 9430: raw sequence lengths - image: 9, agent_pos: 9, action: 9
# Index 9430: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 1084: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 1084: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 7184: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 7184: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 24128: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 24128: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 180: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 180: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 17749: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 17749: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 2545: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 2545: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 21240: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 21240: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 10163: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 10163: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 16218: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 16218: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 11903: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 11903: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 163: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 163: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 13238: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 13238: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Batch shapes: image=torch.Size([32, 2, 3, 96, 96]), agent_pos=torch.Size([32, 2, 2]), action=torch.Size([32, 16, 2])
# <ipython-input-29-9b8081dbf295>:65: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Streaming output truncated to the last 5000 lines.
# ConditionalResidualBlock1D output shape: torch.Size([32, 128, 8])
# Up block 2 output shape: torch.Size([32, 128, 8])
# Upsample 3 output shape: torch.Size([32, 128, 16])
# Selecting skip_idx=1, skip shape: torch.Size([32, 64, 16])
# Concat shape before up block 4: torch.Size([32, 192, 16])
# ConditionalResidualBlock1D input shape: torch.Size([32, 192, 16])
# Conv1dBlock input shape: torch.Size([32, 192, 16])
# Conv1dBlock output shape: torch.Size([32, 64, 16])
# Conv1dBlock input shape: torch.Size([32, 64, 16])
# Conv1dBlock output shape: torch.Size([32, 64, 16])
# ConditionalResidualBlock1D output shape: torch.Size([32, 64, 16])
# Up block 4 output shape: torch.Size([32, 64, 16])
# Before final_conv shape: torch.Size([32, 64, 16])
# Final output shape: torch.Size([32, 2, 16])
# Index 23581: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 23581: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 14231: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 14231: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 6298: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 6298: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 17685: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 17685: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 1610: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 1610: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 8392: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 8392: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 12959: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 12959: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 8164: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 8164: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 5125: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 5125: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 8255: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 8255: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 10328: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 10328: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 6402: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 6402: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 14108: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 14108: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 11648: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 11648: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 22598: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 22598: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 641: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 641: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 5202: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 5202: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 20767: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 20767: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 1834: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 1834: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 5860: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 5860: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 21751: raw sequence lengths - image: 12, agent_pos: 12, action: 12
# Index 21751: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 19231: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 19231: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 13413: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 13413: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 3083: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 3083: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 4794: raw sequence lengths - image: 11, agent_pos: 11, action: 11
# Index 4794: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 15369: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 15369: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 21487: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 21487: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 16183: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 16183: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 19544: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 19544: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 13402: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 13402: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 20826: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 20826: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 22593: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 22593: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Batch shapes: image=torch.Size([32, 2, 3, 96, 96]), agent_pos=torch.Size([32, 2, 2]), action=torch.Size([32, 16, 2])
# Unet input shape: torch.Size([32, 2, 16]), timesteps: torch.Size([32]), global_cond: torch.Size([32, 1028])
# ConditionalResidualBlock1D input shape: torch.Size([32, 2, 16])
# Conv1dBlock input shape: torch.Size([32, 2, 16])
# Conv1dBlock output shape: torch.Size([32, 64, 16])
# Conv1dBlock input shape: torch.Size([32, 64, 16])
# Conv1dBlock output shape: torch.Size([32, 64, 16])
# ConditionalResidualBlock1D output shape: torch.Size([32, 64, 16])
# Down block 0 output shape: torch.Size([32, 64, 16])
# Down block 1 output shape: torch.Size([32, 64, 8])
# ConditionalResidualBlock1D input shape: torch.Size([32, 64, 8])
# Conv1dBlock input shape: torch.Size([32, 64, 8])
# Conv1dBlock output shape: torch.Size([32, 128, 8])
# Conv1dBlock input shape: torch.Size([32, 128, 8])
# Conv1dBlock output shape: torch.Size([32, 128, 8])
# ConditionalResidualBlock1D output shape: torch.Size([32, 128, 8])
# Down block 2 output shape: torch.Size([32, 128, 8])
# Down block 3 output shape: torch.Size([32, 128, 4])
# ConditionalResidualBlock1D input shape: torch.Size([32, 128, 4])
# Conv1dBlock input shape: torch.Size([32, 128, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# Conv1dBlock input shape: torch.Size([32, 256, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# ConditionalResidualBlock1D output shape: torch.Size([32, 256, 4])
# Down block 4 output shape: torch.Size([32, 256, 4])
# ConditionalResidualBlock1D input shape: torch.Size([32, 256, 4])
# Conv1dBlock input shape: torch.Size([32, 256, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# Conv1dBlock input shape: torch.Size([32, 256, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# ConditionalResidualBlock1D output shape: torch.Size([32, 256, 4])
# Mid block output shape: torch.Size([32, 256, 4])
# Selecting skip_idx=5, skip shape: torch.Size([32, 256, 4])
# Concat shape before up block 0: torch.Size([32, 512, 4])
# ConditionalResidualBlock1D input shape: torch.Size([32, 512, 4])
# Conv1dBlock input shape: torch.Size([32, 512, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# Conv1dBlock input shape: torch.Size([32, 256, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# ConditionalResidualBlock1D output shape: torch.Size([32, 256, 4])
# Up block 0 output shape: torch.Size([32, 256, 4])
# Upsample 1 output shape: torch.Size([32, 256, 8])
# Selecting skip_idx=3, skip shape: torch.Size([32, 128, 8])
# Concat shape before up block 2: torch.Size([32, 384, 8])
# ConditionalResidualBlock1D input shape: torch.Size([32, 384, 8])
# Conv1dBlock input shape: torch.Size([32, 384, 8])
# Conv1dBlock output shape: torch.Size([32, 128, 8])
# Conv1dBlock input shape: torch.Size([32, 128, 8])
# Conv1dBlock output shape: torch.Size([32, 128, 8])
# ConditionalResidualBlock1D output shape: torch.Size([32, 128, 8])
# Up block 2 output shape: torch.Size([32, 128, 8])
# Upsample 3 output shape: torch.Size([32, 128, 16])
# Selecting skip_idx=1, skip shape: torch.Size([32, 64, 16])
# Concat shape before up block 4: torch.Size([32, 192, 16])
# ConditionalResidualBlock1D input shape: torch.Size([32, 192, 16])
# Conv1dBlock input shape: torch.Size([32, 192, 16])
# Conv1dBlock output shape: torch.Size([32, 64, 16])
# Conv1dBlock input shape: torch.Size([32, 64, 16])
# Conv1dBlock output shape: torch.Size([32, 64, 16])
# ConditionalResidualBlock1D output shape: torch.Size([32, 64, 16])
# Up block 4 output shape: torch.Size([32, 64, 16])
# Before final_conv shape: torch.Size([32, 64, 16])
# Final output shape: torch.Size([32, 2, 16])
# Index 5580: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 5580: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 14653: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 14653: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 16438: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 16438: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 4205: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 4205: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 8182: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 8182: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 15638: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 15638: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 16587: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 16587: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 17747: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 17747: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 13610: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 13610: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 20455: raw sequence lengths - image: 9, agent_pos: 9, action: 9
# Index 20455: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 23535: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 23535: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 850: raw sequence lengths - image: 11, agent_pos: 11, action: 11
# Index 850: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 3299: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 3299: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 1830: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 1830: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 14482: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 14482: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 11377: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 11377: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 7639: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 7639: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 5724: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 5724: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 2347: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 2347: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 11277: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 11277: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 16703: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 16703: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 14778: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 14778: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 8607: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 8607: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 20417: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 20417: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 3601: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 3601: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 21175: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 21175: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 7435: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 7435: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 2678: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 2678: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 21021: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 21021: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 8533: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 8533: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 12059: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 12059: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 13411: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 13411: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Batch shapes: image=torch.Size([32, 2, 3, 96, 96]), agent_pos=torch.Size([32, 2, 2]), action=torch.Size([32, 16, 2])
# Unet input shape: torch.Size([32, 2, 16]), timesteps: torch.Size([32]), global_cond: torch.Size([32, 1028])
# ConditionalResidualBlock1D input shape: torch.Size([32, 2, 16])
# Conv1dBlock input shape: torch.Size([32, 2, 16])
# Conv1dBlock output shape: torch.Size([32, 64, 16])
# Conv1dBlock input shape: torch.Size([32, 64, 16])
# Conv1dBlock output shape: torch.Size([32, 64, 16])
# ConditionalResidualBlock1D output shape: torch.Size([32, 64, 16])
# Down block 0 output shape: torch.Size([32, 64, 16])
# Down block 1 output shape: torch.Size([32, 64, 8])
# ConditionalResidualBlock1D input shape: torch.Size([32, 64, 8])
# Conv1dBlock input shape: torch.Size([32, 64, 8])
# Conv1dBlock output shape: torch.Size([32, 128, 8])
# Conv1dBlock input shape: torch.Size([32, 128, 8])
# Conv1dBlock output shape: torch.Size([32, 128, 8])
# ConditionalResidualBlock1D output shape: torch.Size([32, 128, 8])
# Down block 2 output shape: torch.Size([32, 128, 8])
# Down block 3 output shape: torch.Size([32, 128, 4])
# ConditionalResidualBlock1D input shape: torch.Size([32, 128, 4])
# Conv1dBlock input shape: torch.Size([32, 128, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# Conv1dBlock input shape: torch.Size([32, 256, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# ConditionalResidualBlock1D output shape: torch.Size([32, 256, 4])
# Down block 4 output shape: torch.Size([32, 256, 4])
# ConditionalResidualBlock1D input shape: torch.Size([32, 256, 4])
# Conv1dBlock input shape: torch.Size([32, 256, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# Conv1dBlock input shape: torch.Size([32, 256, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# ConditionalResidualBlock1D output shape: torch.Size([32, 256, 4])
# Mid block output shape: torch.Size([32, 256, 4])
# Selecting skip_idx=5, skip shape: torch.Size([32, 256, 4])
# Concat shape before up block 0: torch.Size([32, 512, 4])
# ConditionalResidualBlock1D input shape: torch.Size([32, 512, 4])
# Conv1dBlock input shape: torch.Size([32, 512, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# Conv1dBlock input shape: torch.Size([32, 256, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# ConditionalResidualBlock1D output shape: torch.Size([32, 256, 4])
# Up block 0 output shape: torch.Size([32, 256, 4])
# Upsample 1 output shape: torch.Size([32, 256, 8])
# Selecting skip_idx=3, skip shape: torch.Size([32, 128, 8])
# Concat shape before up block 2: torch.Size([32, 384, 8])
# ConditionalResidualBlock1D input shape: torch.Size([32, 384, 8])
# Conv1dBlock input shape: torch.Size([32, 384, 8])
# Conv1dBlock output shape: torch.Size([32, 128, 8])
# Conv1dBlock input shape: torch.Size([32, 128, 8])
# Conv1dBlock output shape: torch.Size([32, 128, 8])
# ConditionalResidualBlock1D output shape: torch.Size([32, 128, 8])
# Up block 2 output shape: torch.Size([32, 128, 8])
# Upsample 3 output shape: torch.Size([32, 128, 16])
# Selecting skip_idx=1, skip shape: torch.Size([32, 64, 16])
# Concat shape before up block 4: torch.Size([32, 192, 16])
# ConditionalResidualBlock1D input shape: torch.Size([32, 192, 16])
# Conv1dBlock input shape: torch.Size([32, 192, 16])
# Conv1dBlock output shape: torch.Size([32, 64, 16])
# Conv1dBlock input shape: torch.Size([32, 64, 16])
# Conv1dBlock output shape: torch.Size([32, 64, 16])
# ConditionalResidualBlock1D output shape: torch.Size([32, 64, 16])
# Up block 4 output shape: torch.Size([32, 64, 16])
# Before final_conv shape: torch.Size([32, 64, 16])
# Final output shape: torch.Size([32, 2, 16])
# Index 16474: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 16474: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 5271: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 5271: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 19666: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 19666: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 16196: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 16196: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 3537: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 3537: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 22750: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 22750: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 3512: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 3512: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 17949: raw sequence lengths - image: 15, agent_pos: 15, action: 15
# Index 17949: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 11049: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 11049: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 2656: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 2656: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 11354: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 11354: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 3321: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 3321: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 5953: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 5953: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 9043: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 9043: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 7611: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 7611: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 20485: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 20485: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 18238: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 18238: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 15519: raw sequence lengths - image: 13, agent_pos: 13, action: 13
# Index 15519: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 4773: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 4773: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 21599: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 21599: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 3345: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 3345: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 7336: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 7336: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 21846: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 21846: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 5363: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 5363: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 6211: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 6211: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 3429: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 3429: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 5197: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 5197: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 3320: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 3320: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 15749: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 15749: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 15956: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 15956: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 16954: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 16954: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 20975: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 20975: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Batch shapes: image=torch.Size([32, 2, 3, 96, 96]), agent_pos=torch.Size([32, 2, 2]), action=torch.Size([32, 16, 2])
# Unet input shape: torch.Size([32, 2, 16]), timesteps: torch.Size([32]), global_cond: torch.Size([32, 1028])
# ConditionalResidualBlock1D input shape: torch.Size([32, 2, 16])
# Conv1dBlock input shape: torch.Size([32, 2, 16])
# Conv1dBlock output shape: torch.Size([32, 64, 16])
# Conv1dBlock input shape: torch.Size([32, 64, 16])
# Conv1dBlock output shape: torch.Size([32, 64, 16])
# ConditionalResidualBlock1D output shape: torch.Size([32, 64, 16])
# Down block 0 output shape: torch.Size([32, 64, 16])
# Down block 1 output shape: torch.Size([32, 64, 8])
# ConditionalResidualBlock1D input shape: torch.Size([32, 64, 8])
# Conv1dBlock input shape: torch.Size([32, 64, 8])
# Conv1dBlock output shape: torch.Size([32, 128, 8])
# Conv1dBlock input shape: torch.Size([32, 128, 8])
# Conv1dBlock output shape: torch.Size([32, 128, 8])
# ConditionalResidualBlock1D output shape: torch.Size([32, 128, 8])
# Down block 2 output shape: torch.Size([32, 128, 8])
# Down block 3 output shape: torch.Size([32, 128, 4])
# ConditionalResidualBlock1D input shape: torch.Size([32, 128, 4])
# Conv1dBlock input shape: torch.Size([32, 128, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# Conv1dBlock input shape: torch.Size([32, 256, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# ConditionalResidualBlock1D output shape: torch.Size([32, 256, 4])
# Down block 4 output shape: torch.Size([32, 256, 4])
# ConditionalResidualBlock1D input shape: torch.Size([32, 256, 4])
# Conv1dBlock input shape: torch.Size([32, 256, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# Conv1dBlock input shape: torch.Size([32, 256, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# ConditionalResidualBlock1D output shape: torch.Size([32, 256, 4])
# Mid block output shape: torch.Size([32, 256, 4])
# Selecting skip_idx=5, skip shape: torch.Size([32, 256, 4])
# Concat shape before up block 0: torch.Size([32, 512, 4])
# ConditionalResidualBlock1D input shape: torch.Size([32, 512, 4])
# Conv1dBlock input shape: torch.Size([32, 512, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# Conv1dBlock input shape: torch.Size([32, 256, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# ConditionalResidualBlock1D output shape: torch.Size([32, 256, 4])
# Up block 0 output shape: torch.Size([32, 256, 4])
# Upsample 1 output shape: torch.Size([32, 256, 8])
# Selecting skip_idx=3, skip shape: torch.Size([32, 128, 8])
# Concat shape before up block 2: torch.Size([32, 384, 8])
# ConditionalResidualBlock1D input shape: torch.Size([32, 384, 8])
# Conv1dBlock input shape: torch.Size([32, 384, 8])
# Conv1dBlock output shape: torch.Size([32, 128, 8])
# Conv1dBlock input shape: torch.Size([32, 128, 8])
# Conv1dBlock output shape: torch.Size([32, 128, 8])
# ConditionalResidualBlock1D output shape: torch.Size([32, 128, 8])
# Up block 2 output shape: torch.Size([32, 128, 8])
# Upsample 3 output shape: torch.Size([32, 128, 16])
# Selecting skip_idx=1, skip shape: torch.Size([32, 64, 16])
# Concat shape before up block 4: torch.Size([32, 192, 16])
# ConditionalResidualBlock1D input shape: torch.Size([32, 192, 16])
# Conv1dBlock input shape: torch.Size([32, 192, 16])
# Conv1dBlock output shape: torch.Size([32, 64, 16])
# Conv1dBlock input shape: torch.Size([32, 64, 16])
# Conv1dBlock output shape: torch.Size([32, 64, 16])
# ConditionalResidualBlock1D output shape: torch.Size([32, 64, 16])
# Up block 4 output shape: torch.Size([32, 64, 16])
# Before final_conv shape: torch.Size([32, 64, 16])
# Final output shape: torch.Size([32, 2, 16])
# Index 10731: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 10731: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 17918: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 17918: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 13410: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 13410: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 23187: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 23187: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 10891: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 10891: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 6266: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 6266: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 48: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 48: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 8581: raw sequence lengths - image: 11, agent_pos: 11, action: 11
# Index 8581: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 4742: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 4742: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 4130: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 4130: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 14912: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 14912: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 18705: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 18705: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 15406: raw sequence lengths - image: 10, agent_pos: 10, action: 10
# Index 15406: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 22742: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 22742: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 10821: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 10821: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 14109: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 14109: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 5721: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 5721: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 16097: raw sequence lengths - image: 11, agent_pos: 11, action: 11
# Index 16097: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 6596: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 6596: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 15613: raw sequence lengths - image: 15, agent_pos: 15, action: 15
# Index 15613: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 24105: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 24105: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 4714: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 4714: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 20345: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 20345: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 3278: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 3278: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 7623: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 7623: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 8074: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 8074: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 1613: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 1613: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 21257: raw sequence lengths - image: 10, agent_pos: 10, action: 10
# Index 21257: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 23673: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 23673: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 12253: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 12253: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 15437: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 15437: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 16313: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 16313: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Batch shapes: image=torch.Size([32, 2, 3, 96, 96]), agent_pos=torch.Size([32, 2, 2]), action=torch.Size([32, 16, 2])
# Unet input shape: torch.Size([32, 2, 16]), timesteps: torch.Size([32]), global_cond: torch.Size([32, 1028])
# ConditionalResidualBlock1D input shape: torch.Size([32, 2, 16])
# Conv1dBlock input shape: torch.Size([32, 2, 16])
# Conv1dBlock output shape: torch.Size([32, 64, 16])
# Conv1dBlock input shape: torch.Size([32, 64, 16])
# Conv1dBlock output shape: torch.Size([32, 64, 16])
# ConditionalResidualBlock1D output shape: torch.Size([32, 64, 16])
# Down block 0 output shape: torch.Size([32, 64, 16])
# Down block 1 output shape: torch.Size([32, 64, 8])
# ConditionalResidualBlock1D input shape: torch.Size([32, 64, 8])
# Conv1dBlock input shape: torch.Size([32, 64, 8])
# Conv1dBlock output shape: torch.Size([32, 128, 8])
# Conv1dBlock input shape: torch.Size([32, 128, 8])
# Conv1dBlock output shape: torch.Size([32, 128, 8])
# ConditionalResidualBlock1D output shape: torch.Size([32, 128, 8])
# Down block 2 output shape: torch.Size([32, 128, 8])
# Down block 3 output shape: torch.Size([32, 128, 4])
# ConditionalResidualBlock1D input shape: torch.Size([32, 128, 4])
# Conv1dBlock input shape: torch.Size([32, 128, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# Conv1dBlock input shape: torch.Size([32, 256, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# ConditionalResidualBlock1D output shape: torch.Size([32, 256, 4])
# Down block 4 output shape: torch.Size([32, 256, 4])
# ConditionalResidualBlock1D input shape: torch.Size([32, 256, 4])
# Conv1dBlock input shape: torch.Size([32, 256, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# Conv1dBlock input shape: torch.Size([32, 256, 4])
# ...
# ConditionalResidualBlock1D output shape: torch.Size([32, 256, 4])
# Down block 4 output shape: torch.Size([32, 256, 4])
# ConditionalResidualBlock1D input shape: torch.Size([32, 256, 4])
# Conv1dBlock input shape: torch.Size([32, 256, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# Conv1dBlock input shape: torch.Size([32, 256, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# ConditionalResidualBlock1D output shape: torch.Size([32, 256, 4])
# Mid block output shape: torch.Size([32, 256, 4])
# Selecting skip_idx=5, skip shape: torch.Size([32, 256, 4])
# Concat shape before up block 0: torch.Size([32, 512, 4])
# ConditionalResidualBlock1D input shape: torch.Size([32, 512, 4])
# Conv1dBlock input shape: torch.Size([32, 512, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# Conv1dBlock input shape: torch.Size([32, 256, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# ConditionalResidualBlock1D output shape: torch.Size([32, 256, 4])
# Up block 0 output shape: torch.Size([32, 256, 4])
# Upsample 1 output shape: torch.Size([32, 256, 8])
# Selecting skip_idx=3, skip shape: torch.Size([32, 128, 8])
# Concat shape before up block 2: torch.Size([32, 384, 8])
# ConditionalResidualBlock1D input shape: torch.Size([32, 384, 8])
# Conv1dBlock input shape: torch.Size([32, 384, 8])
# Conv1dBlock output shape: torch.Size([32, 128, 8])
# Conv1dBlock input shape: torch.Size([32, 128, 8])
# Conv1dBlock output shape: torch.Size([32, 128, 8])
# ConditionalResidualBlock1D output shape: torch.Size([32, 128, 8])
# Up block 2 output shape: torch.Size([32, 128, 8])
# Upsample 3 output shape: torch.Size([32, 128, 16])
# Selecting skip_idx=1, skip shape: torch.Size([32, 64, 16])
# Concat shape before up block 4: torch.Size([32, 192, 16])
# ConditionalResidualBlock1D input shape: torch.Size([32, 192, 16])
# Conv1dBlock input shape: torch.Size([32, 192, 16])
# Conv1dBlock output shape: torch.Size([32, 64, 16])
# Conv1dBlock input shape: torch.Size([32, 64, 16])
# Conv1dBlock output shape: torch.Size([32, 64, 16])
# ConditionalResidualBlock1D output shape: torch.Size([32, 64, 16])
# Up block 4 output shape: torch.Size([32, 64, 16])
# Before final_conv shape: torch.Size([32, 64, 16])
# Final output shape: torch.Size([32, 2, 16])
# Index 20805: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 20805: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 24065: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 24065: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 2716: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 2716: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 8171: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 8171: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 4484: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 4484: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 5888: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 5888: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 9724: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 9724: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 4540: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 4540: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 9443: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 9443: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 18433: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 18433: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 15652: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 15652: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 23457: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 23457: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 8186: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 8186: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 20023: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 20023: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 17271: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 17271: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 23958: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 23958: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 5890: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 5890: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 14587: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 14587: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 23970: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 23970: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 258: raw sequence lengths - image: 15, agent_pos: 15, action: 15
# Index 258: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 7998: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 7998: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 13292: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 13292: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 23961: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 23961: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 11318: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 11318: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 23463: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 23463: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 3012: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 3012: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 8320: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 8320: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 16699: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 16699: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 1303: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 1303: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 13439: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 13439: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 2931: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 2931: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 20468: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 20468: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Batch shapes: image=torch.Size([32, 2, 3, 96, 96]), agent_pos=torch.Size([32, 2, 2]), action=torch.Size([32, 16, 2])
# Unet input shape: torch.Size([32, 2, 16]), timesteps: torch.Size([32]), global_cond: torch.Size([32, 1028])
# ConditionalResidualBlock1D input shape: torch.Size([32, 2, 16])
# Conv1dBlock input shape: torch.Size([32, 2, 16])
# Conv1dBlock output shape: torch.Size([32, 64, 16])
# Conv1dBlock input shape: torch.Size([32, 64, 16])
# Conv1dBlock output shape: torch.Size([32, 64, 16])
# ConditionalResidualBlock1D output shape: torch.Size([32, 64, 16])
# Down block 0 output shape: torch.Size([32, 64, 16])
# Down block 1 output shape: torch.Size([32, 64, 8])
# ConditionalResidualBlock1D input shape: torch.Size([32, 64, 8])
# Conv1dBlock input shape: torch.Size([32, 64, 8])
# Conv1dBlock output shape: torch.Size([32, 128, 8])
# Conv1dBlock input shape: torch.Size([32, 128, 8])
# Conv1dBlock output shape: torch.Size([32, 128, 8])
# ConditionalResidualBlock1D output shape: torch.Size([32, 128, 8])
# Down block 2 output shape: torch.Size([32, 128, 8])
# Down block 3 output shape: torch.Size([32, 128, 4])
# ConditionalResidualBlock1D input shape: torch.Size([32, 128, 4])
# Conv1dBlock input shape: torch.Size([32, 128, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# Conv1dBlock input shape: torch.Size([32, 256, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# ConditionalResidualBlock1D output shape: torch.Size([32, 256, 4])
# Down block 4 output shape: torch.Size([32, 256, 4])
# ConditionalResidualBlock1D input shape: torch.Size([32, 256, 4])
# Conv1dBlock input shape: torch.Size([32, 256, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# Conv1dBlock input shape: torch.Size([32, 256, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# ConditionalResidualBlock1D output shape: torch.Size([32, 256, 4])
# Mid block output shape: torch.Size([32, 256, 4])
# Selecting skip_idx=5, skip shape: torch.Size([32, 256, 4])
# Concat shape before up block 0: torch.Size([32, 512, 4])
# ConditionalResidualBlock1D input shape: torch.Size([32, 512, 4])
# Conv1dBlock input shape: torch.Size([32, 512, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# Conv1dBlock input shape: torch.Size([32, 256, 4])
# Conv1dBlock output shape: torch.Size([32, 256, 4])
# ConditionalResidualBlock1D output shape: torch.Size([32, 256, 4])
# Up block 0 output shape: torch.Size([32, 256, 4])
# Upsample 1 output shape: torch.Size([32, 256, 8])
# Selecting skip_idx=3, skip shape: torch.Size([32, 128, 8])
# Concat shape before up block 2: torch.Size([32, 384, 8])
# ConditionalResidualBlock1D input shape: torch.Size([32, 384, 8])
# Conv1dBlock input shape: torch.Size([32, 384, 8])
# Conv1dBlock output shape: torch.Size([32, 128, 8])
# Conv1dBlock input shape: torch.Size([32, 128, 8])
# Conv1dBlock output shape: torch.Size([32, 128, 8])
# ConditionalResidualBlock1D output shape: torch.Size([32, 128, 8])
# Up block 2 output shape: torch.Size([32, 128, 8])
# Upsample 3 output shape: torch.Size([32, 128, 16])
# Selecting skip_idx=1, skip shape: torch.Size([32, 64, 16])
# Concat shape before up block 4: torch.Size([32, 192, 16])
# ConditionalResidualBlock1D input shape: torch.Size([32, 192, 16])
# Conv1dBlock input shape: torch.Size([32, 192, 16])
# Conv1dBlock output shape: torch.Size([32, 64, 16])
# Conv1dBlock input shape: torch.Size([32, 64, 16])
# Conv1dBlock output shape: torch.Size([32, 64, 16])
# ConditionalResidualBlock1D output shape: torch.Size([32, 64, 16])
# Up block 4 output shape: torch.Size([32, 64, 16])
# Before final_conv shape: torch.Size([32, 64, 16])
# Final output shape: torch.Size([32, 2, 16])
# Index 10138: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 10138: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 6390: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 6390: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 11850: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 11850: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 8471: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 8471: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 1163: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 1163: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 382: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 382: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 15127: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 15127: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 6221: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 6221: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 10189: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 10189: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 11794: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 11794: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 9460: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 9460: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 13495: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 13495: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 11376: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 11376: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 23900: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 23900: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 22016: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 22016: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)
# Index 807: raw sequence lengths - image: 16, agent_pos: 16, action: 16
# Index 807: sample keys: ['image', 'agent_pos', 'action']
#   image shape: (16, 3, 96, 96)
#   agent_pos shape: (16, 2)
#   action shape: (16, 2)

# %%
# inference
max_steps = 200
env = PushTImageEnv()
env.seed(100000)
obs, info = env.reset()
obs_deque = collections.deque([obs] * obs_horizon, maxlen=obs_horizon)
imgs = [env.render(mode='rgb_array')]
rewards = []
done = False
step_idx = 0

with tqdm(total=max_steps, desc="Eval PushTImageEnv") as pbar:
    while not done:
        B = 1
        images = np.stack([x['image'] for x in obs_deque])
        agent_poses = np.stack([x['agent_pos'] for x in obs_deque])
        nagent_poses = normalize_data(agent_poses, stats=stats['agent_pos'])
        nimages = torch.from_numpy(images).to(device, dtype=torch.float32)
        nagent_poses = torch.from_numpy(nagent_poses).to(device, dtype=torch.float32)
        with torch.no_grad():
            image_features = ema_nets['vision_encoder'](nimages)
            obs_features = torch.cat([image_features, nagent_poses], dim=-1)
            obs_cond = obs_features.unsqueeze(0).flatten(start_dim=1)
            noisy_action = torch.randn((B, pred_horizon, action_dim), device=device)
            naction = noisy_action
            noise_scheduler.set_timesteps(num_diffusion_iters)
            for k in noise_scheduler.timesteps:
                noise_pred = ema_nets['noise_pred_net'](naction, k, global_cond=obs_cond)
                naction = noise_scheduler.step(model_output=noise_pred, timestep=k, sample=naction).prev_sample
        naction = naction.detach().cpu().numpy()[0]
        action_pred = unnormalize_data(naction, stats=stats['action'])
        start = obs_horizon - 1
        end = start + action_horizon
        action = action_pred[start:end, :]
        for i in range(len(action)):
            obs, reward, done, _, info = env.step(action[i])
            obs_deque.append(obs)
            rewards.append(reward)
            imgs.append(env.render(mode='rgb_array'))
            step_idx += 1
            pbar.update(1)
            pbar.set_postfix(reward=reward)
            if step_idx > max_steps:
                done = True
            if done:
                break

print('Score: ', max(rewards))
skvideo.io.vwrite('vis.mp4', np.array(imgs))
Video('vis.mp4', embed=True, width=256, height=256)

# %%
# Experiment with action_horizon
action_horizons = [4, 8, 12]
results = {}

for action_horizon in action_horizons:
    print(f"\nTesting action_horizon={action_horizon}")
    # Reset environment and deque
    env = PushTImageEnv()
    env.seed(100000)
    obs, info = env.reset()
    obs_deque = collections.deque([obs] * obs_horizon, maxlen=obs_horizon)
    imgs = [env.render(mode='rgb_array')]
    rewards = []
    done = False
    step_idx = 0
    max_steps = 200

    with tqdm(total=max_steps, desc=f"Eval action_horizon={action_horizon}") as pbar:
        while not done:
            B = 1
            images = np.stack([x['image'] for x in obs_deque])
            agent_poses = np.stack([x['agent_pos'] for x in obs_deque])
            nagent_poses = normalize_data(agent_poses, stats=stats['agent_pos'])
            nimages = torch.from_numpy(images).to(device, dtype=torch.float32)
            nagent_poses = torch.from_numpy(nagent_poses).to(device, dtype=torch.float32)
            with torch.no_grad():
                image_features = ema_nets['vision_encoder'](nimages)
                obs_features = torch.cat([image_features, nagent_poses], dim=-1)
                obs_cond = obs_features.unsqueeze(0).flatten(start_dim=1)
                noisy_action = torch.randn((B, pred_horizon, action_dim), device=device)
                naction = noisy_action
                noise_scheduler.set_timesteps(num_diffusion_iters)
                for k in noise_scheduler.timesteps:
                    noise_pred = ema_nets['noise_pred_net'](naction, k, global_cond=obs_cond)
                    naction = noise_scheduler.step(model_output=noise_pred, timestep=k, sample=naction).prev_sample
            naction = naction.detach().cpu().numpy()[0]
            action_pred = unnormalize_data(naction, stats=stats['action'])
            start = obs_horizon - 1
            end = start + action_horizon
            action = action_pred[start:end, :]
            for i in range(len(action)):
                obs, reward, done, _, info = env.step(action[i])
                obs_deque.append(obs)
                rewards.append(reward)
                imgs.append(env.render(mode='rgb_array'))
                step_idx += 1
                pbar.update(1)
                pbar.set_postfix(reward=reward)
                if step_idx > max_steps:
                    done = True
                if done:
                    break
    results[action_horizon] = max(rewards)
    print(f"Score for action_horizon={action_horizon}: {max(rewards)}")

# Print results
print("\nExperiment Results:")
for ah, score in results.items():
    print(f"action_horizon={ah}: Score={score}")
